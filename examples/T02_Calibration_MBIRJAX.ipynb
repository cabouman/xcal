# %% [markdown]
# # Tutorial 02: Model-Based Spectral Calibration using MBIRJAX
# This tutorial introduces a **model-based spectral calibration** approach using the [MBIRJAX](https://github.com/cabouman/mbirjax)
#  projector.
#
# In this tutorial, we will
# - simulate multi-energy dataset using MBIRJAX projector
#   - simulate CT scans with specific source, filter, and detector configurations.
#   - scan multiple materials at different source voltages to generate multi-energy dataset.
# - model-based spectral calibration
#   - Step 0: Obtain sample masks and calculate forward matrix.
#   - Step 1: Configure Spectral Models including source, filters, and detector(scintillator).
#   - Step 2: Spectral Calibration.

# %% [markdown]
# ## X-ray System Setup
#
# ### Source
# - **Type**: Reflection
# - **Take-off Angle**: 13°
# - **Voltages Used for Scanning**:
#   - 50 kV
#   - 100 kV
#   - 150 kV
#
# ### Filter
# - **Material**: Aluminum (Al)
# - **Thickness**: 3 mm
#
# ### Detector
# - **Material**: Cesium Iodide (CsI)
# - **Thickness**: 0.33 mm
#
# ### Samples
# - **Shapes**: Rods with 0.5 mm radius
# - **Materials**:
#   - Vanadium (V)
#   - Aluminum (Al)
#   - Titanium (Ti)
#   - Magnesium (Mg)
# - **Height**: 0.2 mm
#
# ### CT Geometry
# - **Beam Type**: Parallel Beam
# - **Detector Specifications**:
#   - **Pixel Size**: 0.01 mm × 0.01 mm
#   - **Scan Shape**: 50 × 512 pixels
# - **Number of Views**: 64

# %%
import numpy as np
import matplotlib.pyplot as plt

max_simkV = 180 # keV
takeoff_angle = 13 # degree
voltage_list = [40, 80, 180] # keV
mas_list = [0.01,0.01,0.01] # Milliampere-seconds

fltr_mat = 'Al' # filter material
fltr_th = 3 # filter thickness in mm

det_mat = 'CsI' # scintillator material
det_density = 4.51 # scintillator density g/cm^3
det_th = 0.33 # scintillator thickness in mm

sample_mats = ['V', 'Al', 'Ti', 'Mg']
sample_radius = 0.5 # sample diameter in mm


ct_info = {
    "Geometry": "Parallel",
    "psize": [0.01, 0.01],  # Width and height in mm
    "rsize": [0.01, 0.01],
    "shape": [50, 512],     # Rows and columns
    "NViews": 64
}

# %% [markdown]
# ## A. Simulate multi-energy dataset using MBIRJAX projector

# %% [markdown]
# ### A01. Ground Truth Source Spectra
# In this tutorial,
# - use spekpy to generate X-ray source spectum.
# - the description of 2 used functions from spekpy is shown below by the help function.

# %%
import spekpy as sp
help(sp.Spek.__init__)
# Out:
# Help on function __init__ in module spekpy.SpekPy:
#
# __init__(self, kvp=None, th=None, dk=None, mu_data_source=None, physics=None, x=None, y=None, z=None, mas=None, brem=None, char=None, obli=None, comment=None, targ=None, shift=None, init_default=True)
#     Constructor method for the Spek class
#
#     SEE THE WIKI PAGES FOR MORE INFO:
#     https://bitbucket.org/spekpy/spekpy_release/wiki/Further_information
#
#     :param float kvp: tube potential [kV] (default: depends on target)
#     :param float th: anode angle [degrees] (default: 12 degrees)
#     :param float dk: energy bin width [keV] (default: 0.5 keV)
#     :param string: mu_data_source (default: depends on physics model)
#         options: ('pene' or 'nist')
#     :param float physics: physics model (default: 'casim')
#         options: ('casim', 'kqp', 'spekpy-v1', 'spekcalc',
#                   'diff', 'uni', 'sim', 'classical')
#     :param float x: displacement from central axis in anode-cathode
#         direction [cm] (default: 0 cm)
#     :param float y: displacement from central axis in orthogonal
#         direction [cm] (default: 0 cm)
#     :param float z: focus-to-detector distance [cm] (default: 100 cm)
#     :param float mas: the tube current-time product [mAs] (default: 1 mAs)
#     :param logical brem: whether bremsstrahlung x rays requested
#         (default: true)
#     :param logical char: whether characteristic x rays requested
#         (default: true)
#     :param logical obli: whether increased oblique paths through filtration
#         are assumed for off axis positions (default: true)
#     :param string comment: any text annotation the user wishes to add
#     :param string targ: the anode target material (default: 'W')
#         options: ('W', 'Mo', or 'Rh')
#     :param float shift: optional fraction of an energy bin to shift the
#         energy bins (useful when matching to measurements) (default: 0.0)

# %%
help(sp.Spek.get_spectrum)
# Out:
# Help on function get_spectrum in module spekpy.SpekPy:
#
# get_spectrum(self, edges=False, flu=True, diff=True, sig=None, addend=False, **kwargs)
#     A method to get the energy and spectrum for the parameters in the
#     current spekpy state
#
#     :param bool edges: Keyword argument to determine whether midbin or edge
#         of bins data are returned
#     :param bool addend: Keyword argument to determine whether a zero
#         end point is added to the spectrum
#     :param bool flu: Whether to return fluence or energy-fluence
#     :param bool diff: Whether to return spectrum differential in energy
#     :param kwargs: Keyword arguments to change parameters that are used for
#         the calculation
#     :return array k: Array with photon energies (mid-bin or edge values)
#         [keV]
#     :return array spk: Array with corresponding photon fluences
#         [Photons cm^-2 keV^-1], [Photons cm^-2] or [Photons cm^-2 keV^1]
#         depending of values of flu and diff inputs

# %%
max_simkV = max(voltage_list)
takeoff_angle = 13

# Define energy bins from 1.5 keV up to (max_simkV - 0.5) keV.
energies = np.linspace(1.5, max_simkV - 0.5, max_simkV-1)

# Initialize an empty list to store the generated source spectra.
gt_src_spec_list = []

for case_i, simkV in enumerate(voltage_list):
    # Generate the X-ray spectrum model with Spekpy for each voltage.
    # kvp is source voltage
    # th is anode angle
    # dk is energy bin size
    # z is focus-to-detector distance [cm], use source-detector distance instead and convert mm to cm.
    # mas is current-time product mA*s
    # char=True requests characteristic x rays.
    s = sp.Spek(kvp=simkV, th=takeoff_angle, dk=1,z=1, mas=mas_list[case_i], char=True)
    
    # Return data at the mid of a bin or the edges of a bin.
    k, phi_k = s.get_spectrum(edges=False)  # Retrieve energy bins and fluence spectrum [Photons cm^-2 keV^-1]
    
    # Adjust the fluence for the detector pixel area.
    phi_k = phi_k * ((ct_info['psize'][0] / 10) * (ct_info['psize'][1] / 10))  # Convert pixel size from cm² to mm²

    # Initialize a zero-filled spectrum array with length max_simkV.
    src_spec = np.zeros(max_simkV-1)
    src_spec[:simkV-1] = phi_k  # Assign spectrum values starting from 1.5 keV

    # Add the processed spectrum for this voltage to the list.
    gt_src_spec_list.append(src_spec)

# Convert the list of source spectra to a numpy array for easy handling.
gt_src_spec_list = np.array(gt_src_spec_list)

# Plot each generated source spectrum.
for src_i, gt_src_spec in enumerate(gt_src_spec_list):
    plt.plot(energies, gt_src_spec, label='%d kV' % voltage_list[src_i])

plt.title('Ground Truth Source Spectra')
plt.xlabel('Energy (keV)')
plt.ylabel('Photons per pixel [$mm^{-2}$ $keV^{-1}$]')
plt.grid()
plt.legend()

# %% [markdown]
# #### A02. Ground Truth Filter Response
# Filter response is defined as
# $$
# f(E) = e^{-\mu(m, E)\cdot t}
# $$
# where $t$ is thickness; $\mu$ is linear attenuation coefficient(LAC), which depends on photon energy and material $m$ formula and density.

# %%
from xcal import get_filter_response
from xcal.chem_consts._periodictabledata import density

# get_filter_response returns a ratio of passing through photons.
# F(E) = e^(-\mu_{mat}(E)*thickness) 
# \mu_{mat}(E) = mac{mat}(E) * density
# where \mu denotes linear attenuation coefficient; mac means mass attenuation coefficient.
gt_fltr = get_filter_response(energies, fltr_mat, density[fltr_mat], fltr_th)

plt.plot(energies, gt_fltr, label='3mm Al')
plt.title('Ground Truth Filter Response')
plt.legend()
plt.xlabel('Energy (keV)')
plt.grid()

# %% [markdown]
# ### A03. Ground Truth Detector Response
#
# Converted energy from a X-ray photon with energy from 1 to 180 keV.
#
# Detector response is defined as
# $$
# D(E) =\frac{\mu_{en}(m, E)}{\mu(m, E)} (1 - e^{-\mu(m, E)\cdot t} )
# $$
# where $t$ is scintillator thickness; $\mu$ is linear attenuation coefficient(LAC), which depends on photon energy $E$ and material $m$ formula and density; $\mu_en$ is linear energy-absorption coefficient(LAC).

# %%
from xcal import get_scintillator_response
from xcal.chem_consts._periodictabledata import density

# get_scintillator_response returns converted energy per photon at energy E.
# D(E) = -\mu_en/\mu * (1-e^(-\mu(E)*thickness))
# \mu(E) = mac(E) * density
# \mu_en(E) = mac_en(E) * density
# where \mu denotes linear attenuation coefficient; mac means mass attenuation coefficient.
# where \mu_en denotes linear energy-absorption coefficient; mac_en means mass energy-absorption coefficient.
gt_det = get_scintillator_response(energies, det_mat, det_density, det_th)

plt.plot(energies, gt_det, label='%.2fmm %s'%(det_th, det_mat))
plt.title('Ground Truth Scintillator Response')
plt.legend()
plt.xlabel('Energy (keV)')
plt.grid()

# %% [markdown]
# ### A04. Linear Attenuation Coefficients of homogenous samples

# %%
from xcal.chem_consts import get_lin_att_c_vs_E
help(get_lin_att_c_vs_E)
# Out:
# Help on function get_lin_att_c_vs_E in module xcal.chem_consts._consts_from_table:
#
# get_lin_att_c_vs_E(density, formula, energy_vector)
#     Calculate the linear attenuation coefficient (mu) as a function of energy,
#     using mass attenuation coefficients from the NIST website:
#     https://physics.nist.gov/PhysRefData/XrayMassCoef/tab3.html.
#
#     Author: Wenrui Li, Purdue University
#     Date: 04/12/2022
#
#     Parameters
#     ----------
#     density : float
#         Density of the material in g/cm^3.
#     formula : str/dict
#         Chemical formula of the compound, either as a string or a dict.
#         For example, "H2O" and {"H": 2, "O": 1} are both acceptable.
#     energy_vector : list/numpy.ndarray
#         Energy (units: keV) list or 1D array for which beta values are calculated.
#
#     Returns
#     -------
#     numpy.ndarray
#         Linear attenuation coefficient values in mm^-1, with the same size as energy_vector.

# %%
# Scanned Homogeneous Rods
# Density for homogenous material is stored in the imported density dictionary
mat_density = [density[formula] for formula in sample_mats]
lac_vs_E_list = [get_lin_att_c_vs_E(den, formula, energies) for den, formula in zip(mat_density, sample_mats)]

# Plot LAC
for lac_vs_E,mat in zip(lac_vs_E_list, sample_mats):
    plt.plot(energies, lac_vs_E, label=mat)
plt.yscale('log')
plt.title(r'Linear Attenuation Coefficient $\mu$ ($mm^{-1}$)')
plt.xlabel('Energy (keV)')
plt.grid()
plt.legend()

# %% [markdown]
# ### A05. GT X-ray System Spectral Responses

# %%
gt_spec_list = [gt_source * gt_fltr  * gt_det for gt_source in gt_src_spec_list]
for spec_i, gt_spec in enumerate(gt_spec_list):
    plt.plot(energies, gt_spec/np.trapezoid(gt_spec,energies), label='%d kV'%voltage_list[spec_i])
plt.legend()
plt.title('Ground Truth: X-ray System Spectral Response')
plt.xlabel('Energy (keV)')
plt.grid()
plt.legend()

# %% [markdown]
# ### A06. Masks for 4 homogenous samples
#
# Obtain a list of mask for each corresponding homogenous sample rod.
# These masks is then used to calculate the forward matrix for the transmission function.

# %%
from xcal._utils import Gen_Circle
help(Gen_Circle.__init__)
# Out:
# Help on function __init__ in module xcal._utils:
#
# __init__(self, canvas_shape, pixel_size)
#     Initialize the Circle class.
#
#     Parameters:
#     canvas_shape (tuple): The shape of the canvas, in pixels.
#     pixel_size (tuple): The size of a pixel, in the same units as the canvas.

# %%
help(Gen_Circle.generate_mask)
# Out:
# Help on function generate_mask in module xcal._utils:
#
# generate_mask(self, radius, center=None)
#     Generate a binary mask for the circle.
#
#     Parameters:
#     radius (int): The radius of the circle, in pixels.
#     center (tuple): The center of the circle.
#
#     Returns:
#     ndarray: A 2D numpy array where points inside the circle are marked as True and points outside are marked as False.

# %%
# Define parameters for 4 cylinders with 0.5mm radius, evenly distributed on a circle with a radius of 1.5mm.
Radius = [sample_radius for _ in range(len(sample_mats))]  # Radius of each cylindrical cross-section in mm
arrange_with_radius = 1.5  # Radius of the circle on which cylinder centers are distributed (in mm)

# Calculate center positions for each cylinder, evenly spaced around the circular arrangement
centers = [[np.sin(rad_angle) * arrange_with_radius, np.cos(rad_angle) * arrange_with_radius]
           for rad_angle in np.linspace(-np.pi / 2, -np.pi / 2 + np.pi * 2, len(sample_mats), endpoint=False)]

# Generate 3D masks for each cylinder
# Obtain a list of mask for each corresponding homogenous sample rod. 
# These masks is then used to calculate the forward matrix for the transmission function.
mask_list = []
for mat_id, mat in enumerate(sample_mats):
    # Initialize a circular mask generator for 2D slices
    # Use the number of column pixels to define a canvas
    circle = Gen_Circle((ct_info["shape"][1], ct_info["shape"][1]), 
                        (ct_info["rsize"][0], ct_info["rsize"][1])) # Image volume size
    # Create a 3D mask array for the current cylinder by repeating the circular 2D mask across slices
    mask_3d = np.array([circle.generate_mask(Radius[mat_id], centers[mat_id]) 
                        for i in range(ct_info["shape"][0])]).transpose((1,2,0))
    mask_list.append(mask_3d)

# Below just for display    
# Initialize the phantom array to hold combined cylinder masks
phantom = np.zeros(mask_list[0].shape)    

# Combine all masks into the phantom, weighted by the linear attenuation coefficients for each material
for mat_id, mat in enumerate(sample_mats):
    phantom += mask_list[mat_id] * np.mean(lac_vs_E_list[mat_id])

# Display a slice of the phantom (e.g., 26th slice) to show cross-sectional circles of cylinders
plt.imshow(phantom[:,:,25], extent=[-2.56, 2.56, -2.56, 2.56], origin='lower')

# Annotate each circle with its corresponding material name
for mat_id, mat in enumerate(sample_mats):
    plt.text(centers[mat_id][1], centers[mat_id][0], mat, fontsize=15, ha='right', color='red')
plt.title('Phantom: 4 homogenous samples')
# Out:
# Text(0.5, 1.0, 'Phantom: 4 homogenous samples')

# %% [markdown]
# ### A07. Setup forward projector with MBIRJAX

# %%
import time
import mbirjax

class fw_projector:
    def __init__(self, angles, num_rows, num_channels, delta_pixel=1):
        """

        Parameters
        ----------
        energies
        N_views
        psize
        xcenter
        arange
        """
        self.angles = angles
        self.num_rows = num_rows
        self.num_channels = num_channels
        self.delta_pixel = delta_pixel
        self.sinogram_shape = (len(angles), self.num_rows, self.num_channels)

    def forward(self, mask):
        """

        Parameters
        ----------
        mask : numpy.ndarray
            3D mask for pure solid object.

        Returns
        -------
        lai : numpy.ndarray
            Linear attenuation integral, of size M measurement * N energy bins.

        """

        ct_model_for_generation = mbirjax.ParallelBeamModel(self.sinogram_shape, self.angles)
        # Print out model parameters
        ct_model_for_generation.print_params()
        projections = ct_model_for_generation.forward_project(mask) * self.delta_pixel

        return projections
    
angles = np.linspace(-np.pi/2, np.pi, ct_info['NViews'], endpoint=False)
projector = fw_projector(angles, num_rows=ct_info["shape"][0], num_channels=ct_info["shape"][1], delta_pixel=ct_info["psize"][0])

# %% [markdown]
# ### A08. Calculate Attenuation Matrix
# We let $ \mu_k(E) $ denote the LAC of the $k^\text{th}$ homogeneous sample at energy $E$, and let $L_{k, i}$ denote the path length through the $k^{th}$ material at projection $i$ for samples $k=0, \ldots, K-1$.
# The attenuation matrix is calculated as below,
# $$
# A(E) = \exp \left\{-\sum_{k=0}^{K-1} \mu_k(E) L_{k, i}\right\}
# $$
#
# Notice that $L_{k, i}$ is calcuated by projecting $k^\text{th}$ mask in mask_list with a projector defined in A07.
# One should create the “projector” object in a similar way defined in A07 if use CT projector other than MBIRJAX.

# %%
from xcal import calc_forward_matrix
spec_F = calc_forward_matrix(mask_list, lac_vs_E_list, projector)
# Out:
# WARNING:2025-05-07 01:19:15,054:jax._src.xla_bridge:967: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----

# %% [markdown]
# ### A09. Simulate Transmission Data

# %%
trans_list = []
for case_i, gt_spec in zip(np.arange(len(gt_spec_list)), gt_spec_list):
    # Obtain the converted energy, which is proportional to the detected visible light photons by the camera.
    # gt_spec is the converted energy without an object.
    # Notice that, trapezoid does the energy integration.
    trans = np.trapezoid(spec_F * gt_spec, energies, axis=-1) # Object scan
    trans_0 = np.trapezoid(gt_spec, energies, axis=-1) # Air scan value
    # Add poisson noise.
    # The noise level can be adjusted by changing the mas, the current-time product in the beginning of this tutorial.
    trans_noise = np.random.poisson(trans).astype(np.float32)
    trans_noise /= trans_0

    # Store noisy transmission data.
    trans_list.append(trans_noise)

# %%
for case_i, gt_spec in enumerate(gt_spec_list):
    plt.plot(trans_list[case_i][3, 25], label=f'{voltage_list[case_i]} keV')
plt.legend()
plt.grid()
plt.title('Simulated Transmission Data')
# Out:
# Text(0.5, 1.0, 'Simulated Transmission Data')

# %% [markdown]
# ## B. Spectral Calibration

# %% [markdown]
# ### B01. FBP Reconstruction using MBIRJAX
# Reconstructing one CT scan using MBIR.

# %%
# Reconstructing one CT scan using MBIR.
sino = -np.log(trans_list[-1]).astype(np.float32)
sino = np.ascontiguousarray(sino, dtype=np.float32) # shape is numAngles, numRows, numCols


startTime = time.time()
sinogram_shape = (len(angles), ct_info["shape"][0], ct_info["shape"][1])
ct_model_for_recon = mbirjax.ParallelBeamModel(sinogram_shape, angles)
sharpness = 1.0
ct_model_for_recon.set_params(sharpness=sharpness)
recon, recon_params = ct_model_for_recon.recon(sino, weights=None, max_iterations=20) # shape is numZ, numY, numX
recon = recon/ct_info["psize"][0] # convert ALU^-1 to mm^-1
recon = recon.transpose((2,0,1))
print('Reconstruction Elapsed Time: ' + str(time.time()-startTime))
# Out:
# GPU used for: none
# Estimated GPU memory required = 0.000 GB, available = 0.000 GB
# Estimated CPU memory required = 1.111 GB, available = 64.000 GB
# Starting direct recon for initial reconstruction
# Initializing error sinogram
# Computing Hessian diagonal
# Starting VCD iterations
#
# After iteration 0 of a max of 20: Pct change=28.4719, Forward loss=2.4480
# Relative step size (alpha)=0.23, Error sino RMSE=0.0284
# Number subsets = 1
#
# After iteration 1 of a max of 20: Pct change=36.1704, Forward loss=0.8518
# Relative step size (alpha)=1.46, Error sino RMSE=0.0099
# Number subsets = 16
#
# After iteration 2 of a max of 20: Pct change=15.6713, Forward loss=0.6962
# Relative step size (alpha)=1.50, Error sino RMSE=0.0081
# Number subsets = 64
#
# After iteration 3 of a max of 20: Pct change=8.0426, Forward loss=0.6840
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 4 of a max of 20: Pct change=4.8482, Forward loss=0.6814
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 5 of a max of 20: Pct change=3.4376, Forward loss=0.6844
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 6 of a max of 20: Pct change=2.6294, Forward loss=0.6838
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 7 of a max of 20: Pct change=2.1359, Forward loss=0.6849
# Relative step size (alpha)=1.50, Error sino RMSE=0.0080
# Number subsets = 128
#
# After iteration 8 of a max of 20: Pct change=1.7808, Forward loss=0.6841
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 9 of a max of 20: Pct change=1.5213, Forward loss=0.6843
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 10 of a max of 20: Pct change=1.3185, Forward loss=0.6836
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 11 of a max of 20: Pct change=1.1665, Forward loss=0.6836
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 12 of a max of 20: Pct change=1.0388, Forward loss=0.6831
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 13 of a max of 20: Pct change=0.9355, Forward loss=0.6830
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 14 of a max of 20: Pct change=0.8524, Forward loss=0.6825
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 15 of a max of 20: Pct change=0.7878, Forward loss=0.6824
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 16 of a max of 20: Pct change=0.7297, Forward loss=0.6821
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 17 of a max of 20: Pct change=0.6808, Forward loss=0.6820
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 18 of a max of 20: Pct change=0.6420, Forward loss=0.6817
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 19 of a max of 20: Pct change=0.6121, Forward loss=0.6816
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
# Reconstruction Elapsed Time: 81.72657203674316

# %%
plt.imshow(recon[25])
plt.colorbar()
plt.title('Reconstruction')
# Out:
# Text(0.5, 1.0, 'Reconstruction')

# %% [markdown]
# ### B02. Circle Detection (Optional)
# The circle detection provides a coarse bounding box for object segmentation.
# One can manually set the bounding box for the object segmentation, if the sample is not cylindrical.
#
# Below is an example to use detect_hough_circles to detect circles on the $25^{th}$ slice of the reconstruction.

# %%
from xcal.phantom import detect_hough_circles

# %%
help(detect_hough_circles)
# Out:
# Help on function detect_hough_circles in module xcal.phantom:
#
# detect_hough_circles(phantom, radius_range=None, vmin=0, vmax=None, min_dist=100, HoughCircles_params1=300, HoughCircles_params2=1)
#     Detects circles in an image using the Hough Circle Transform.
#
#     Args:
#         phantom (numpy.ndarray): The 2D image to detect circles in.
#         radius_range (list of int, optional): The minimum and maximum radius of
#             circles to detect. Defaults to a range based on the image size.
#         vmin (int, optional): Minimum value for clipping the image before
#             detection. Defaults to 0.
#         vmax (int, optional): Maximum value for clipping the image before
#             detection. If None, the 90th percentile of the image is used.
#             Defaults to None.
#         min_dist (int, optional): Minimum distance between the centers of the
#             detected circles. If too small, multiple neighbor circles may be
#             falsely detected in addition to a true one. If too large, some
#             circles may be missed. Defaults to 100.
#         HoughCircles_params1 (float, optional): Upper threshold for the internal edge detection.
#         HoughCircles_params2 (float, optional): Threshold for center detection, which influences the detection sensitivity. Large param2 leads to fewer detected circles.
#
#     Returns:
#         numpy.ndarray: An array of detected circles, each represented by the
#             center coordinates (x, y) and radius. Returns an empty array if no
#             circles are detected.

# %%
from matplotlib.patches import Circle
import math

plt.imshow(recon[25],origin='lower')
plt.colorbar()
# Get the current axes.
ax = plt.gca()
circles = detect_hough_circles(recon[25], 
                               radius_range=(45, 55), 
                               vmin=0.00, vmax=0.1, 
                               min_dist=200,
                               HoughCircles_params2=10)

# Below is for display and sort the detected circles.
# x is horizontal axis, y is vertical axis. 
circles_values = np.array([np.mean(recon[25][int(y-r):int(y+r),int(x-r):int(x+r)]) for x,y,r in circles])
# Sort `circles` based on the order in `circles_values`
circles = [cir for _, cir in sorted(zip(circles_values, circles))]
# Rearrange based on material ['V', 'Al', 'Ti', 'Mg'] 
circles = [circles[i] for i in [3,1,2,0]]

# Create and add circles to the plot.
for x, y, radius in circles:
    circle = Circle((x, y), radius, color='red', fill=False)
    ax.add_patch(circle)

# Optionally set the aspect of the plot to be equal.
# This makes sure that the circles are not skewed.
ax.set_aspect('equal')
plt.title('Circle Detection')
# Show the plot with the circles.
plt.show()

# %% [markdown]
# ### B03. Segment Object to get 3D Mask
#
# segment_object is a function to segment one sample from background.

# %%
from xcal.phantom import segment_object

# %%
help(segment_object)
# Out:
# Help on function segment_object in module xcal.phantom:
#
# segment_object(phantom, vmin, vmax, canny_sigma, roi_radius=None, bbox=None)
#     Segments an object within a given region of interest (ROI) or bounding box in an image.
#
#     This function creates a segmentation mask for an object in an image. The image values
#     are clipped and normalized based on provided minimum and maximum values. Canny edge
#     detection is then applied to the normalized image. The edges are filled to create a
#     binary mask that segments the object.
#
#     Args:
#         phantom (np.array): The input image to segment.
#         vmin (float): The minimum value for clipping the image.
#         vmax (float): The maximum value for clipping the image.
#         canny_sigma (float): The standard deviation for the Gaussian filter used in
#                              Canny edge detection.
#         roi_radius (int, optional): The radius of the circular region of interest. If not
#                                     provided, it defaults to half the image size.
#         bbox (tuple of int, optional): The bounding box within which to perform segmentation,
#                                        specified as (r_min, c_min, r_max, c_max). If not
#                                        provided, the entire image is used.
#
#     Returns:
#         np.array: A binary segmentation mask of the object.

# %%
est_mask_list = []
bbox_half_size = int(np.mean([cir[2] for cir in circles])*1.1)
# Manually set the threshold based on above plot.
vmin_list = [0.02,0.01,0.2,0.01]
vmax_list = [0.7,0.02,0.4,0.02]
# Loop through each slice to get 3D mask.
for vi,cir in enumerate(circles):
    xcenter, ycenter, r = cir
    # Segment object with 3D mask
    # Set different vmin and vmax for different samples.
    # Set bbox to restrict a box region for object segmentation.
    est_mask = [segment_object(
        recon[i], 
        vmin_list[vi], 
        vmax_list[vi], 
        10, # Canny sigma in canny edge detection. Larger value is more possible to connect to a line.
        roi_radius=None,
        bbox=(
            int(ycenter - bbox_half_size),
            int(xcenter - bbox_half_size),
            int(ycenter + bbox_half_size),
            int(xcenter + bbox_half_size)
        )) for i in range(len(recon))]
    est_mask_list.append(np.array(est_mask))

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 8))

for j in range(len(est_mask_list)):
    ax = axs.flat[j]
    est_mask = est_mask_list[j]
    gtmask = mask_list[j]
    # Display the image or the difference image.
#     ax.imshow(est_mask[25],origin='lower')
    ax.imshow(est_mask[25].astype('float32')-gtmask[:,:,25].astype('float32'),vmin=-1,vmax=1,origin='lower')
# Adjust the layout
plt.tight_layout()
plt.title('Difference between estimated masks and GT mask.')
plt.show()

# %%
# Define colors for each mask
colors = ['b', 'g', 'r', 'm']  # Blue, Green, Red, Magenta for each est_mask

# Plot the 3D masks using a scatter plot with different colors
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

for i, est_mask in enumerate(est_mask_list):
    # Get the coordinates of the points where the mask is 1
    z, y, x = np.where(est_mask == 1)
    ax.scatter(x, y, z, color=colors[i], marker='o', s=1, alpha=0.7, label=sample_mats[i])

# Set labels and title
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("Estimated 3D Binary Mask Visualization with Different Colors")
plt.legend()
plt.show()

# %% [markdown]
# ### B04. Calculate Forward Matrix with Estimated 3D Masks

# %%
# Only use 8 different views for spectral calibration
NViews_For_MBSC = 8
projector2 = fw_projector(angles[::ct_info["NViews"]//NViews_For_MBSC], num_rows=ct_info["shape"][0], num_channels=ct_info["shape"][1], delta_pixel=ct_info["psize"][0])

# %%
for i in range(len(est_mask_list)):
    est_mask_list[i] = est_mask_list[i].transpose((1,2,0))
est_spec_F = calc_forward_matrix(est_mask_list, lac_vs_E_list, projector2)
# Out:
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----

# %% [markdown]
# ### B05. X-ray System Model Configuration

# %%
from xcal.models import Reflection_Source, Filter, Scintillator
from xcal.defs import Material

# %%
# Use Spekpy to generate a source spectra dictionary.
takeoff_angles = np.linspace(5,45,11)
src_spec_list = []
for case_i,simkV in enumerate(voltage_list):
    for ta in takeoff_angles:
        # Generate the X-ray spectrum model with Spekpy for each voltage.
        s = sp.Spek(kvp=simkV, th=ta, dk=1,z=1, mas=mas_list[case_i], char=True)
        k, phi_k = s.get_spectrum(edges=False)  # Retrieve energy bins and fluence spectrum [Photons cm^-2 keV^-1]

        # Adjust the fluence for the detector pixel area.
        phi_k = phi_k * ((ct_info['psize'][0] / 10) * (ct_info['psize'][1] / 10))  # Convert pixel size from mm² to cm²

        # Initialize a zero-filled spectrum array with length max_simkV.
        src_spec = np.zeros(max_simkV-1)
        src_spec[:simkV-1] = phi_k  # Assign spectrum values starting from 1.5 keV

        # Add the processed spectrum for this voltage to the list.
        src_spec_list.append(src_spec)

src_spec_list = np.array(src_spec_list)
src_spec_list = src_spec_list.reshape((len(voltage_list),len(takeoff_angles),-1))

# %%
# Configure the Reflection Source Model
# Reflection_Source is a PyTorch module that supports gradient descent.
# Reflection_Source initializes with specified source voltage and takeoff angle.
# The set_src_spec_list method assigns a dictionary for each source configuration.
# Reflection_Source.forward() provides interpolated dictionary components for each source.

# Source voltage is set to be fixed by setting minbound and maxbound to None.
# Takeoff angle is estimated in range [5,45] with inital value 25 degree.
sources = [Reflection_Source(voltage=(voltage, None, None), takeoff_angle=(25, 5, 45), single_takeoff_angle=True)
           for voltage in voltage_list]
# Assigning the dictionaries for each source.
for src_i, source in enumerate(sources):
    source.set_src_spec_list(energies, src_spec_list, voltage_list, takeoff_angles)

# %%
# Both the filter and scintillator contain discrete and continuous parameters.
# All continuous parameters are defined using a tuple format with an initial value, minimum bound, and maximum bound.
# Any other format is recognized as a discrete parameter.
# Concatenating all component instances (sources, filters, scintillator) into a list, called spectral configuration like [source, filter_1, scintillator_1], 
# allows the Estimator defined in B07 to recognize all parameters, whether discrete or continuous for a scan.
# The spec_models collects all spectral configuration. Each spectral configuration corresponding to a scan.
# The Estimator will then automatically determine all possible combinations for the discrete parameters and optimize the continous parameters.


# Configure Filter Model
# Knowns: Use one filter for both scans.
# Possible filter materials: Al and Cu.
psb_fltr_mat = [Material(formula='Al', density=2.702), 
                Material(formula='Cu', density=8.92)]
filter_1 = Filter(psb_fltr_mat, thickness=(5, 0, 10))

# Configure Scintillator Model
# Knowns: Use one scintillator for both scans.
# Possible scintillator materials
scint_params_list = [
    {'formula': 'CsI', 'density': 4.51},
    {'formula': 'Gd3Al2Ga3O12', 'density': 6.63},
    {'formula': 'Lu3Al5O12', 'density': 6.73},
    {'formula': 'CdWO4', 'density': 7.9},
    {'formula': 'Y3Al5O12', 'density': 4.56},
    {'formula': 'Bi4Ge3O12', 'density': 7.13},
    {'formula': 'Gd2O2S', 'density': 7.32}
]
psb_scint_mat = [Material(formula=scint_p['formula'], density=scint_p['density']) for scint_p in scint_params_list]
scintillator_1 = Scintillator(materials=psb_scint_mat, thickness=(0.25, 0.01, 0.5))

# For each scan using a different source voltage, we define a different total spectral model.
# Each spectral model is a list containing source, filters, and scintillator models. 
# Allow filter_1, ..., filter_n.
spec_models = [[source, filter_1, scintillator_1] for source in sources]

# %% [markdown]
# ### B06. Spectral Calibration with Simulated Multi-Energy Data

# %%
trans_list[0].shape
# Out:
# (64, 50, 512)

# %%
# Build Training Set
# Use first 8 views and center 2 slices.
train_rads = [trans[::ct_info["NViews"]//NViews_For_MBSC,10:-10:10] for trans in trans_list]

# Assume a same forward matrix for different scans at different voltages.
forward_matrices = [est_spec_F[:,10:-10:10] for i in range(len(voltage_list))]

print("Training Measurement Shape: \n", train_rads[0].shape,train_rads[1].shape,train_rads[2].shape)
print("Training Forward Matrix Shape: \n",forward_matrices[0].shape,forward_matrices[1].shape,forward_matrices[2].shape)
# Out:
# Training Measurement Shape:
#  (8, 3, 512) (8, 3, 512) (8, 3, 512)
# Training Forward Matrix Shape:
#  (8, 3, 512, 179) (8, 3, 512, 179) (8, 3, 512, 179)

# %%
from xcal.estimate import Estimate

learning_rate = 0.01 # 0.01 for NNAT_LBFGS and 0.001 for Adam
max_iterations = 5000 # 5000 ~ 10000 would be enough
stop_threshold = 1e-6
optimizer_type = 'NNAT_LBFGS' # Can also use Adam.

Estimator = Estimate(energies)
# For each scan, add data and calculated forward matrix to Estimator.
for nrad, forward_matrix, concatenate_models in zip(train_rads, forward_matrices, spec_models):
    Estimator.add_data(nrad, forward_matrix, concatenate_models, weight=None)

# Fit data
Estimator.fit(learning_rate=learning_rate,
              max_iterations=max_iterations,
              stop_threshold=stop_threshold,
              optimizer_type=optimizer_type,
              loss_type='transmission',
              logpath=None,
              num_processes=1) # Parallel computing for multiple cpus.
# Out:
# Number of cases for different discrete parameters: 14
# 2025-05-07 01:22:17,876  - Start Estimation.
# 2025-05-07 01:22:18,454  - Initial cost: 1.736105e-03
# 2025-05-07 01:22:19,861  - Iteration: 5
# 2025-05-07 01:22:20,092  - Cost: 0.0007968990248627961
# 2025-05-07 01:22:20,093  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:20,093  - Filter_2_thickness: 4.236132621765137
# 2025-05-07 01:22:20,093  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:20,093  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:20,093  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:20,093  - Reflection_Source_takeoff_angle: 25.254356384277344
# 2025-05-07 01:22:20,093  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:20,094  - Scintillator_2_thickness: 0.25356367230415344
# 2025-05-07 01:22:20,094  -
# 2025-05-07 01:22:21,135  - Iteration: 10
# 2025-05-07 01:22:21,413  - Cost: 0.0006638765335083008
# 2025-05-07 01:22:21,413  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:21,414  - Filter_2_thickness: 3.9577949047088623
# 2025-05-07 01:22:21,414  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:21,414  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:21,414  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:21,414  - Reflection_Source_takeoff_angle: 24.96295166015625
# 2025-05-07 01:22:21,414  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:21,414  - Scintillator_2_thickness: 0.2630610167980194
# 2025-05-07 01:22:21,414  -
# 2025-05-07 01:22:22,557  - Iteration: 15
# 2025-05-07 01:22:22,828  - Cost: 0.0006179731572046876
# 2025-05-07 01:22:22,828  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:22,828  - Filter_2_thickness: 3.7779760360717773
# 2025-05-07 01:22:22,828  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:22,828  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:22,828  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:22,828  - Reflection_Source_takeoff_angle: 24.366226196289062
# 2025-05-07 01:22:22,828  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:22,828  - Scintillator_2_thickness: 0.27816852927207947
# 2025-05-07 01:22:22,828  -
# 2025-05-07 01:22:23,883  - Iteration: 20
# 2025-05-07 01:22:24,134  - Cost: 0.0005583468591794372
# 2025-05-07 01:22:24,135  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:24,135  - Filter_2_thickness: 3.562859058380127
# 2025-05-07 01:22:24,135  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:24,135  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:24,135  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:24,135  - Reflection_Source_takeoff_angle: 22.641374588012695
# 2025-05-07 01:22:24,135  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:24,135  - Scintillator_2_thickness: 0.31599557399749756
# 2025-05-07 01:22:24,135  -
# 2025-05-07 01:22:25,155  - Iteration: 25
# 2025-05-07 01:22:25,412  - Cost: 0.0005094623193144798
# 2025-05-07 01:22:25,412  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:25,412  - Filter_2_thickness: 3.42415714263916
# 2025-05-07 01:22:25,412  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:25,413  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:25,413  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:25,413  - Reflection_Source_takeoff_angle: 20.154300689697266
# 2025-05-07 01:22:25,413  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:25,413  - Scintillator_2_thickness: 0.3547769784927368
# 2025-05-07 01:22:25,413  -
# 2025-05-07 01:22:26,458  - Iteration: 30
# 2025-05-07 01:22:26,719  - Cost: 0.0004984947154298425
# 2025-05-07 01:22:26,719  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:26,720  - Filter_2_thickness: 3.3264851570129395
# 2025-05-07 01:22:26,720  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:26,720  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:26,720  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:26,720  - Reflection_Source_takeoff_angle: 18.626842498779297
# 2025-05-07 01:22:26,720  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:26,720  - Scintillator_2_thickness: 0.37306398153305054
# 2025-05-07 01:22:26,720  -
# 2025-05-07 01:22:27,613  - Iteration: 35
# 2025-05-07 01:22:28,127  - Cost: 0.0004969171714037657
# 2025-05-07 01:22:28,127  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:28,127  - Filter_2_thickness: 3.2939023971557617
# 2025-05-07 01:22:28,127  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:28,127  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:28,127  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:28,127  - Reflection_Source_takeoff_angle: 18.09926986694336
# 2025-05-07 01:22:28,127  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:28,127  - Scintillator_2_thickness: 0.37880584597587585
# 2025-05-07 01:22:28,127  -
# 2025-05-07 01:22:29,132  - Iteration: 40
# 2025-05-07 01:22:29,374  - Cost: 0.0004965115804225206
# 2025-05-07 01:22:29,374  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:29,374  - Filter_2_thickness: 3.275696039199829
# 2025-05-07 01:22:29,374  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:29,374  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:29,374  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:29,374  - Reflection_Source_takeoff_angle: 17.815959930419922
# 2025-05-07 01:22:29,375  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:29,375  - Scintillator_2_thickness: 0.38210511207580566
# 2025-05-07 01:22:29,375  -
# 2025-05-07 01:22:30,377  - Iteration: 45
# 2025-05-07 01:22:30,499  - Cost: 0.0004964482504874468
# 2025-05-07 01:22:30,500  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:30,500  - Filter_2_thickness: 3.269956588745117
# 2025-05-07 01:22:30,500  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:30,500  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:30,500  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:30,500  - Reflection_Source_takeoff_angle: 17.729751586914062
# 2025-05-07 01:22:30,500  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:30,500  - Scintillator_2_thickness: 0.3833964169025421
# 2025-05-07 01:22:30,500  -
# 2025-05-07 01:22:31,543  - Iteration: 50
# 2025-05-07 01:22:31,802  - Cost: 0.0004964271793141961
# 2025-05-07 01:22:31,803  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:31,803  - Filter_2_thickness: 3.266482353210449
# 2025-05-07 01:22:31,803  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:31,803  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:31,803  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:31,803  - Reflection_Source_takeoff_angle: 17.6883602142334
# 2025-05-07 01:22:31,803  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:31,803  - Scintillator_2_thickness: 0.38445958495140076
# 2025-05-07 01:22:31,803  -
# 2025-05-07 01:22:36,682  - Stopping at epoch 53 because updates are too small.
# 2025-05-07 01:22:36,683  - Cost: 0.0004964236286468804
# 2025-05-07 01:22:36,683  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:36,683  - Filter_2_thickness: 3.2658729553222656
# 2025-05-07 01:22:36,683  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:36,683  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:36,683  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:36,683  - Reflection_Source_takeoff_angle: 17.686447143554688
# 2025-05-07 01:22:36,683  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:22:36,683  - Scintillator_2_thickness: 0.3848515748977661
# 2025-05-07 01:22:36,683  -
# 2025-05-07 01:22:36,694  - Start Estimation.
# 2025-05-07 01:22:36,775  - Initial cost: 2.733790e-03
# 2025-05-07 01:22:38,009  - Iteration: 5
# 2025-05-07 01:22:38,291  - Cost: 0.0024503269232809544
# 2025-05-07 01:22:38,291  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:38,292  - Filter_2_thickness: 4.564085960388184
# 2025-05-07 01:22:38,292  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:38,292  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:38,292  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:38,292  - Reflection_Source_takeoff_angle: 24.30644416809082
# 2025-05-07 01:22:38,292  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-07 01:22:38,292  - Scintillator_2_thickness: 0.24547673761844635
# 2025-05-07 01:22:38,292  -
# 2025-05-07 01:22:39,435  - Iteration: 10
# 2025-05-07 01:22:39,724  - Cost: 0.0022622509859502316
# 2025-05-07 01:22:39,725  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:39,725  - Filter_2_thickness: 4.077823162078857
# 2025-05-07 01:22:39,725  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:39,725  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:39,725  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:39,725  - Reflection_Source_takeoff_angle: 20.799877166748047
# 2025-05-07 01:22:39,725  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-07 01:22:39,725  - Scintillator_2_thickness: 0.24090325832366943
# 2025-05-07 01:22:39,725  -
# 2025-05-07 01:22:45,208  - Stopping at epoch 12 because updates are too small.
# 2025-05-07 01:22:45,208  - Cost: 0.0021894145756959915
# 2025-05-07 01:22:45,208  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:45,208  - Filter_2_thickness: 3.8829779624938965
# 2025-05-07 01:22:45,208  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:45,208  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:45,208  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:45,208  - Reflection_Source_takeoff_angle: 18.938051223754883
# 2025-05-07 01:22:45,208  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-07 01:22:45,208  - Scintillator_2_thickness: 0.23914574086666107
# 2025-05-07 01:22:45,208  -
# 2025-05-07 01:22:45,216  - Start Estimation.
# 2025-05-07 01:22:45,331  - Initial cost: 3.349994e-03
# 2025-05-07 01:22:46,499  - Iteration: 5
# 2025-05-07 01:22:46,798  - Cost: 0.003059151116758585
# 2025-05-07 01:22:46,798  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:46,798  - Filter_2_thickness: 4.458999156951904
# 2025-05-07 01:22:46,799  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:46,799  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:46,799  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:46,799  - Reflection_Source_takeoff_angle: 23.827922821044922
# 2025-05-07 01:22:46,799  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-07 01:22:46,799  - Scintillator_2_thickness: 0.25904497504234314
# 2025-05-07 01:22:46,799  -
# 2025-05-07 01:22:47,837  - Iteration: 10
# 2025-05-07 01:22:48,091  - Cost: 0.002578496700152755
# 2025-05-07 01:22:48,092  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:48,092  - Filter_2_thickness: 3.2860755920410156
# 2025-05-07 01:22:48,092  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:48,092  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:48,092  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:48,092  - Reflection_Source_takeoff_angle: 17.21243667602539
# 2025-05-07 01:22:48,092  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-07 01:22:48,092  - Scintillator_2_thickness: 0.31621047854423523
# 2025-05-07 01:22:48,092  -
# 2025-05-07 01:22:53,185  - Stopping at epoch 13 because updates are too small.
# 2025-05-07 01:22:53,185  - Cost: 0.00225787959061563
# 2025-05-07 01:22:53,185  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:53,185  - Filter_2_thickness: 2.538613796234131
# 2025-05-07 01:22:53,185  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:53,186  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:53,186  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:53,186  - Reflection_Source_takeoff_angle: 11.65902328491211
# 2025-05-07 01:22:53,186  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-07 01:22:53,186  - Scintillator_2_thickness: 0.3607690930366516
# 2025-05-07 01:22:53,186  -
# 2025-05-07 01:22:53,193  - Start Estimation.
# 2025-05-07 01:22:53,272  - Initial cost: 3.307857e-03
# 2025-05-07 01:22:54,505  - Iteration: 5
# 2025-05-07 01:22:54,785  - Cost: 0.0015118408482521772
# 2025-05-07 01:22:54,785  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:54,785  - Filter_2_thickness: 3.8255538940429688
# 2025-05-07 01:22:54,785  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:54,785  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:54,785  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:54,785  - Reflection_Source_takeoff_angle: 25.008956909179688
# 2025-05-07 01:22:54,785  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:22:54,785  - Scintillator_2_thickness: 0.26269006729125977
# 2025-05-07 01:22:54,786  -
# 2025-05-07 01:22:55,854  - Iteration: 10
# 2025-05-07 01:22:56,181  - Cost: 0.001139438129030168
# 2025-05-07 01:22:56,181  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:56,182  - Filter_2_thickness: 3.2730040550231934
# 2025-05-07 01:22:56,182  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:56,182  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:56,182  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:56,182  - Reflection_Source_takeoff_angle: 24.038806915283203
# 2025-05-07 01:22:56,182  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:22:56,182  - Scintillator_2_thickness: 0.2953222095966339
# 2025-05-07 01:22:56,182  -
# 2025-05-07 01:22:57,290  - Iteration: 15
# 2025-05-07 01:22:57,668  - Cost: 0.000907223904505372
# 2025-05-07 01:22:57,668  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:57,668  - Filter_2_thickness: 2.8710458278656006
# 2025-05-07 01:22:57,668  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:57,668  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:57,668  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:57,668  - Reflection_Source_takeoff_angle: 21.976821899414062
# 2025-05-07 01:22:57,668  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:22:57,668  - Scintillator_2_thickness: 0.3451926112174988
# 2025-05-07 01:22:57,668  -
# 2025-05-07 01:22:58,796  - Iteration: 20
# 2025-05-07 01:22:59,112  - Cost: 0.0006394240772351623
# 2025-05-07 01:22:59,112  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:22:59,113  - Filter_2_thickness: 2.5583913326263428
# 2025-05-07 01:22:59,113  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:22:59,113  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:22:59,113  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:22:59,113  - Reflection_Source_takeoff_angle: 16.78207778930664
# 2025-05-07 01:22:59,113  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:22:59,113  - Scintillator_2_thickness: 0.41149213910102844
# 2025-05-07 01:22:59,113  -
# 2025-05-07 01:23:00,124  - Iteration: 25
# 2025-05-07 01:23:00,391  - Cost: 0.0005878530791960657
# 2025-05-07 01:23:00,391  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:00,392  - Filter_2_thickness: 2.4165549278259277
# 2025-05-07 01:23:00,392  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:00,392  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:00,392  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:00,392  - Reflection_Source_takeoff_angle: 14.171127319335938
# 2025-05-07 01:23:00,392  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:23:00,392  - Scintillator_2_thickness: 0.4339160919189453
# 2025-05-07 01:23:00,392  -
# 2025-05-07 01:23:01,528  - Iteration: 30
# 2025-05-07 01:23:01,798  - Cost: 0.0005780502688139677
# 2025-05-07 01:23:01,798  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:01,799  - Filter_2_thickness: 2.356294631958008
# 2025-05-07 01:23:01,799  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:01,799  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:01,799  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:01,799  - Reflection_Source_takeoff_angle: 13.121851921081543
# 2025-05-07 01:23:01,799  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:23:01,799  - Scintillator_2_thickness: 0.44467973709106445
# 2025-05-07 01:23:01,799  -
# 2025-05-07 01:23:03,433  - Iteration: 35
# 2025-05-07 01:23:03,738  - Cost: 0.0005758142797276378
# 2025-05-07 01:23:03,739  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:03,739  - Filter_2_thickness: 2.336249828338623
# 2025-05-07 01:23:03,739  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:03,739  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:03,739  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:03,739  - Reflection_Source_takeoff_angle: 12.844446182250977
# 2025-05-07 01:23:03,739  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:23:03,739  - Scintillator_2_thickness: 0.4530307352542877
# 2025-05-07 01:23:03,739  -
# 2025-05-07 01:23:04,693  - Iteration: 40
# 2025-05-07 01:23:04,966  - Cost: 0.0005746628157794476
# 2025-05-07 01:23:04,966  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:04,966  - Filter_2_thickness: 2.3287696838378906
# 2025-05-07 01:23:04,966  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:04,966  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:04,966  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:04,966  - Reflection_Source_takeoff_angle: 12.882055282592773
# 2025-05-07 01:23:04,966  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:23:04,966  - Scintillator_2_thickness: 0.462423175573349
# 2025-05-07 01:23:04,966  -
# 2025-05-07 01:23:06,088  - Iteration: 45
# 2025-05-07 01:23:12,300  - Cost: 0.00057066953741014
# 2025-05-07 01:23:12,300  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:12,300  - Filter_2_thickness: 2.348262310028076
# 2025-05-07 01:23:12,300  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:12,300  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:12,301  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:12,301  - Reflection_Source_takeoff_angle: 14.244956016540527
# 2025-05-07 01:23:12,301  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:23:12,301  - Scintillator_2_thickness: 0.49997153878211975
# 2025-05-07 01:23:12,301  -
# 2025-05-07 01:23:12,301  - Stopping at epoch 45 because updates are too small.
# 2025-05-07 01:23:12,301  - Cost: 0.00057066953741014
# 2025-05-07 01:23:12,301  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:12,301  - Filter_2_thickness: 2.348262310028076
# 2025-05-07 01:23:12,301  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:12,301  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:12,302  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:12,302  - Reflection_Source_takeoff_angle: 14.244956016540527
# 2025-05-07 01:23:12,302  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:23:12,302  - Scintillator_2_thickness: 0.49997153878211975
# 2025-05-07 01:23:12,302  -
# 2025-05-07 01:23:12,309  - Start Estimation.
# 2025-05-07 01:23:12,386  - Initial cost: 6.198009e-03
# 2025-05-07 01:23:13,605  - Iteration: 5
# 2025-05-07 01:23:13,875  - Cost: 0.00578325055539608
# 2025-05-07 01:23:13,875  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:13,875  - Filter_2_thickness: 5.190148830413818
# 2025-05-07 01:23:13,875  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:13,875  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:13,875  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:13,876  - Reflection_Source_takeoff_angle: 22.2139949798584
# 2025-05-07 01:23:13,876  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-07 01:23:13,876  - Scintillator_2_thickness: 0.2760545015335083
# 2025-05-07 01:23:13,876  -
# 2025-05-07 01:23:15,481  - Iteration: 10
# 2025-05-07 01:23:15,832  - Cost: 0.00453636609017849
# 2025-05-07 01:23:15,833  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:15,833  - Filter_2_thickness: 4.51515007019043
# 2025-05-07 01:23:15,833  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:15,833  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:15,833  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:15,833  - Reflection_Source_takeoff_angle: 6.237462043762207
# 2025-05-07 01:23:15,833  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-07 01:23:15,833  - Scintillator_2_thickness: 0.4156917631626129
# 2025-05-07 01:23:15,833  -
# 2025-05-07 01:23:20,806  - Stopping at epoch 11 because updates are too small.
# 2025-05-07 01:23:20,806  - Cost: 0.004536367952823639
# 2025-05-07 01:23:20,806  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:20,807  - Filter_2_thickness: 4.51515007019043
# 2025-05-07 01:23:20,807  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:20,807  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:20,807  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:20,807  - Reflection_Source_takeoff_angle: 6.2374653816223145
# 2025-05-07 01:23:20,807  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-07 01:23:20,807  - Scintillator_2_thickness: 0.41569191217422485
# 2025-05-07 01:23:20,807  -
# 2025-05-07 01:23:20,814  - Start Estimation.
# 2025-05-07 01:23:20,894  - Initial cost: 4.337988e-03
# 2025-05-07 01:23:22,049  - Iteration: 5
# 2025-05-07 01:23:22,368  - Cost: 0.0025125504471361637
# 2025-05-07 01:23:22,368  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:22,368  - Filter_2_thickness: 3.587186574935913
# 2025-05-07 01:23:22,369  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:22,369  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:22,369  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:22,369  - Reflection_Source_takeoff_angle: 24.460832595825195
# 2025-05-07 01:23:22,369  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:23:22,369  - Scintillator_2_thickness: 0.2799686789512634
# 2025-05-07 01:23:22,369  -
# 2025-05-07 01:23:23,454  - Iteration: 10
# 2025-05-07 01:23:23,737  - Cost: 0.0018660929054021835
# 2025-05-07 01:23:23,737  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:23,737  - Filter_2_thickness: 2.770524024963379
# 2025-05-07 01:23:23,737  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:23,737  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:23,737  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:23,737  - Reflection_Source_takeoff_angle: 22.249406814575195
# 2025-05-07 01:23:23,737  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:23:23,738  - Scintillator_2_thickness: 0.3406149744987488
# 2025-05-07 01:23:23,738  -
# 2025-05-07 01:23:24,864  - Iteration: 15
# 2025-05-07 01:23:25,135  - Cost: 0.0010740056168287992
# 2025-05-07 01:23:25,135  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:25,135  - Filter_2_thickness: 2.081352710723877
# 2025-05-07 01:23:25,135  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:25,135  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:25,135  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:25,135  - Reflection_Source_takeoff_angle: 15.115443229675293
# 2025-05-07 01:23:25,135  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:23:25,135  - Scintillator_2_thickness: 0.44246697425842285
# 2025-05-07 01:23:25,135  -
# 2025-05-07 01:23:26,291  - Iteration: 20
# 2025-05-07 01:23:26,478  - Cost: 0.0006177190807648003
# 2025-05-07 01:23:26,478  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:26,478  - Filter_2_thickness: 1.6469835042953491
# 2025-05-07 01:23:26,478  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:26,478  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:26,478  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:26,479  - Reflection_Source_takeoff_angle: 6.959805488586426
# 2025-05-07 01:23:26,479  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:23:26,479  - Scintillator_2_thickness: 0.4995790719985962
# 2025-05-07 01:23:26,479  -
# 2025-05-07 01:23:27,715  - Iteration: 25
# 2025-05-07 01:23:27,988  - Cost: 0.0006113718845881522
# 2025-05-07 01:23:27,988  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:27,988  - Filter_2_thickness: 1.573928713798523
# 2025-05-07 01:23:27,988  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:27,988  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:27,989  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:27,989  - Reflection_Source_takeoff_angle: 6.437740802764893
# 2025-05-07 01:23:27,989  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:23:27,989  - Scintillator_2_thickness: 0.5
# 2025-05-07 01:23:27,989  -
# 2025-05-07 01:23:29,126  - Iteration: 30
# 2025-05-07 01:23:29,392  - Cost: 0.0006104566855356097
# 2025-05-07 01:23:29,392  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:29,393  - Filter_2_thickness: 1.5397499799728394
# 2025-05-07 01:23:29,393  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:29,393  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:29,393  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:29,393  - Reflection_Source_takeoff_angle: 6.202157020568848
# 2025-05-07 01:23:29,393  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:23:29,393  - Scintillator_2_thickness: 0.5
# 2025-05-07 01:23:29,393  -
# 2025-05-07 01:23:35,493  - Stopping at epoch 32 because updates are too small.
# 2025-05-07 01:23:35,494  - Cost: 0.0006104469066485763
# 2025-05-07 01:23:35,494  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:35,494  - Filter_2_thickness: 1.5380382537841797
# 2025-05-07 01:23:35,494  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:35,494  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:35,494  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:35,494  - Reflection_Source_takeoff_angle: 6.17974853515625
# 2025-05-07 01:23:35,494  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:23:35,494  - Scintillator_2_thickness: 0.5
# 2025-05-07 01:23:35,494  -
# 2025-05-07 01:23:35,502  - Start Estimation.
# 2025-05-07 01:23:35,575  - Initial cost: 2.909246e-03
# 2025-05-07 01:23:36,756  - Iteration: 5
# 2025-05-07 01:23:37,009  - Cost: 0.0021920723374933004
# 2025-05-07 01:23:37,010  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:37,010  - Filter_2_thickness: 4.326990127563477
# 2025-05-07 01:23:37,010  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:37,010  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:37,010  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:37,010  - Reflection_Source_takeoff_angle: 24.63187599182129
# 2025-05-07 01:23:37,010  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-07 01:23:37,010  - Scintillator_2_thickness: 0.240998774766922
# 2025-05-07 01:23:37,010  -
# 2025-05-07 01:23:38,071  - Iteration: 10
# 2025-05-07 01:23:38,334  - Cost: 0.002023551845923066
# 2025-05-07 01:23:38,334  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:38,334  - Filter_2_thickness: 3.9794602394104004
# 2025-05-07 01:23:38,334  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:38,335  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:38,335  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:38,335  - Reflection_Source_takeoff_angle: 22.925640106201172
# 2025-05-07 01:23:38,335  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-07 01:23:38,335  - Scintillator_2_thickness: 0.23190222680568695
# 2025-05-07 01:23:38,335  -
# 2025-05-07 01:23:39,350  - Iteration: 15
# 2025-05-07 01:23:39,736  - Cost: 0.0017205190379172564
# 2025-05-07 01:23:39,736  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:39,736  - Filter_2_thickness: 3.2032153606414795
# 2025-05-07 01:23:39,737  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:39,737  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:39,737  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:39,737  - Reflection_Source_takeoff_angle: 14.280213356018066
# 2025-05-07 01:23:39,737  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-07 01:23:39,737  - Scintillator_2_thickness: 0.19779951870441437
# 2025-05-07 01:23:39,737  -
# 2025-05-07 01:23:44,174  - Stopping at epoch 16 because updates are too small.
# 2025-05-07 01:23:44,174  - Cost: 0.0017205183394253254
# 2025-05-07 01:23:44,175  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-07 01:23:44,175  - Filter_2_thickness: 3.203214406967163
# 2025-05-07 01:23:44,175  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:44,175  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:44,175  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:44,175  - Reflection_Source_takeoff_angle: 14.28021240234375
# 2025-05-07 01:23:44,175  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-07 01:23:44,175  - Scintillator_2_thickness: 0.19779951870441437
# 2025-05-07 01:23:44,175  -
# 2025-05-07 01:23:44,182  - Start Estimation.
# 2025-05-07 01:23:44,252  - Initial cost: 1.664757e-01
# 2025-05-07 01:23:49,037  - Stopping at epoch 2 because updates are too small.
# 2025-05-07 01:23:49,037  - Cost: 0.16554242372512817
# 2025-05-07 01:23:49,037  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-07 01:23:49,037  - Filter_2_thickness: 0.0
# 2025-05-07 01:23:49,037  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:49,037  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:49,037  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:49,038  - Reflection_Source_takeoff_angle: 26.213611602783203
# 2025-05-07 01:23:49,038  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-07 01:23:49,038  - Scintillator_2_thickness: 0.2389550656080246
# 2025-05-07 01:23:49,038  -
# 2025-05-07 01:23:49,045  - Start Estimation.
# 2025-05-07 01:23:49,122  - Initial cost: 1.669890e-01
# 2025-05-07 01:23:55,738  - Stopping at epoch 2 because updates are too small.
# 2025-05-07 01:23:55,739  - Cost: 0.16106106340885162
# 2025-05-07 01:23:55,739  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-07 01:23:55,739  - Filter_2_thickness: 0.0
# 2025-05-07 01:23:55,739  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:23:55,739  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:23:55,739  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:23:55,739  - Reflection_Source_takeoff_angle: 26.202070236206055
# 2025-05-07 01:23:55,739  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-07 01:23:55,739  - Scintillator_2_thickness: 0.23768973350524902
# 2025-05-07 01:23:55,739  -
# 2025-05-07 01:23:55,746  - Start Estimation.
# 2025-05-07 01:23:55,819  - Initial cost: 1.680738e-01
# 2025-05-07 01:24:01,326  - Stopping at epoch 2 because updates are too small.
# 2025-05-07 01:24:01,326  - Cost: 0.15652190148830414
# 2025-05-07 01:24:01,326  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-07 01:24:01,326  - Filter_2_thickness: 0.0
# 2025-05-07 01:24:01,326  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:24:01,326  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:24:01,326  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:24:01,326  - Reflection_Source_takeoff_angle: 26.18990707397461
# 2025-05-07 01:24:01,326  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-07 01:24:01,326  - Scintillator_2_thickness: 0.24694451689720154
# 2025-05-07 01:24:01,326  -
# 2025-05-07 01:24:01,334  - Start Estimation.
# 2025-05-07 01:24:01,405  - Initial cost: 1.670054e-01
# 2025-05-07 01:24:08,675  - Stopping at epoch 2 because updates are too small.
# 2025-05-07 01:24:08,676  - Cost: 0.1422795057296753
# 2025-05-07 01:24:08,676  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-07 01:24:08,676  - Filter_2_thickness: 0.0
# 2025-05-07 01:24:08,676  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:24:08,676  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:24:08,676  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:24:08,676  - Reflection_Source_takeoff_angle: 26.19626808166504
# 2025-05-07 01:24:08,676  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-07 01:24:08,676  - Scintillator_2_thickness: 0.25037750601768494
# 2025-05-07 01:24:08,676  -
# 2025-05-07 01:24:08,683  - Start Estimation.
# 2025-05-07 01:24:08,757  - Initial cost: 1.644296e-01
# 2025-05-07 01:24:18,905  - Stopping at epoch 1 because updates are too small.
# 2025-05-07 01:24:18,906  - Cost: 0.16442960500717163
# 2025-05-07 01:24:18,906  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-07 01:24:18,906  - Filter_2_thickness: 5.0
# 2025-05-07 01:24:18,906  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:24:18,906  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:24:18,906  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:24:18,906  - Reflection_Source_takeoff_angle: 24.999998092651367
# 2025-05-07 01:24:18,906  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-07 01:24:18,906  - Scintillator_2_thickness: 0.25
# 2025-05-07 01:24:18,906  -
# 2025-05-07 01:24:18,913  - Start Estimation.
# 2025-05-07 01:24:19,070  - Initial cost: 1.669202e-01
# 2025-05-07 01:24:25,715  - Stopping at epoch 2 because updates are too small.
# 2025-05-07 01:24:25,716  - Cost: 0.13784480094909668
# 2025-05-07 01:24:25,716  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-07 01:24:25,716  - Filter_2_thickness: 0.0
# 2025-05-07 01:24:25,716  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:24:25,716  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:24:25,716  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:24:25,716  - Reflection_Source_takeoff_angle: 26.202909469604492
# 2025-05-07 01:24:25,716  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-07 01:24:25,716  - Scintillator_2_thickness: 0.2409420907497406
# 2025-05-07 01:24:25,716  -
# 2025-05-07 01:24:25,723  - Start Estimation.
# 2025-05-07 01:24:25,797  - Initial cost: 1.678586e-01
# 2025-05-07 01:24:31,289  - Stopping at epoch 2 because updates are too small.
# 2025-05-07 01:24:31,290  - Cost: 0.14613747596740723
# 2025-05-07 01:24:31,290  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-07 01:24:31,290  - Filter_2_thickness: 0.0
# 2025-05-07 01:24:31,290  - Reflection_Source_1_voltage: 40.0
# 2025-05-07 01:24:31,290  - Reflection_Source_2_voltage: 80.0
# 2025-05-07 01:24:31,290  - Reflection_Source_3_voltage: 180.0
# 2025-05-07 01:24:31,290  - Reflection_Source_takeoff_angle: 26.175193786621094
# 2025-05-07 01:24:31,290  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-07 01:24:31,290  - Scintillator_2_thickness: 0.2341877818107605
# 2025-05-07 01:24:31,290  -

# %% [markdown]
# ### B07. Result Analysis

# %%
import torch

# Get the estimated effective response for each source voltage.
# Make sure to convert to numpy array from tensor before plotting.
est_sp = Estimator.get_spectra()

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i in range(3):
    ax = axs[i]
    with torch.no_grad():
        ax.plot(energies[:voltage_list[i]-1], (gt_spec_list[i]/np.trapezoid(gt_spec_list[i],energies))[:voltage_list[i]-1],
                label='Ground Truth')
        es = est_sp[i].numpy()
        es /= np.trapezoid(es,energies)
        ax.plot(energies[:voltage_list[i]-1], es[:voltage_list[i]-1], '--', label='Estimate')

    ax.legend()
    ax.set_title(f'{voltage_list[i]} kV Spectral Response')

fig.suptitle('Comparison of Ground Truth and Estimate')
plt.show()

# %%
import pandas as pd

# Return a dictionary containing the estimated parameters.
res_params = Estimator.get_params()

# Ground Truth values
ground_truth = {
    "takeoff_angle (degree)": takeoff_angle,
    "fltr_mat": fltr_mat,
    "fltr_th (mm)": fltr_th,
    "det_mat": det_mat,
    "det_th (mm)": det_th,
}

# Estimated values from res_params
# .item() to return value for an estiamted continous parameter.
# material with .formula is because the class Material contains both formula and density.
estimated = {
    "takeoff_angle (degree)": res_params['Reflection_Source_takeoff_angle'].item(),
    "fltr_mat": res_params['Filter_2_material'].formula,
    "fltr_th (mm)": res_params['Filter_2_thickness'].item(),
    "det_mat": res_params['Scintillator_2_material'].formula,
    "det_th (mm)": res_params['Scintillator_2_thickness'].item(),
}

# Combine into a DataFrame for comparison
df = pd.DataFrame({'Ground Truth': ground_truth, 'Estimated': estimated})

# Display the DataFrame
df
# Out:
#                        Ground Truth  Estimated
# takeoff_angle (degree)           13  17.686447
# fltr_mat                         Al         Al
# fltr_th (mm)                      3   3.265873
# det_mat                         CsI        CsI
# det_th (mm)                    0.33   0.384852
