# %% [markdown]
# # Tutorial 02: Model-Based Spectral Calibration using MBIRJAX
# This tutorial introduces a **model-based spectral calibration** approach using the [MBIRJAX](https://github.com/cabouman/mbirjax)
#  projector.
#
# In this tutorial, we will
# - simulate multi-energy dataset using MBIRJAX projector
#   - simulate CT scans with specific source, filter, and detector configurations.
#   - scan multiple materials at different source voltages to generate multi-energy dataset.
# - model-based spectral calibration
#   - Step 0: Obtain sample masks and calculate forward matrix.
#   - Step 1: Configure Spectral Models including source, filters, and detector(scintillator).
#   - Step 2: Spectral Calibration.

# %% [markdown]
# ## X-ray System Setup
#
# ### Source
# - **Type**: Reflection
# - **Take-off Angle**: 13°
# - **Voltages Used for Scanning**:
#   - 50 kV
#   - 100 kV
#   - 150 kV
#
# ### Filter
# - **Material**: Aluminum (Al)
# - **Thickness**: 3 mm
#
# ### Detector
# - **Material**: Cesium Iodide (CsI)
# - **Thickness**: 0.33 mm
#
# ### Samples
# - **Shapes**: Rods with 0.5 mm radius
# - **Materials**:
#   - Vanadium (V)
#   - Aluminum (Al)
#   - Titanium (Ti)
#   - Magnesium (Mg)
# - **Height**: 0.2 mm
#
# ### CT Geometry
# - **Beam Type**: Parallel Beam
# - **Detector Specifications**:
#   - **Pixel Size**: 0.01 mm × 0.01 mm
#   - **Scan Shape**: 50 × 512 pixels
# - **Number of Views**: 64

# %%
import numpy as np
import matplotlib.pyplot as plt

max_simkV = 180 # keV
takeoff_angle = 13 # degree
voltage_list = [40, 80, 180] # keV
mas_list = [0.01,0.01,0.01] # Milliampere-seconds

fltr_mat = 'Al' # filter material
fltr_th = 3 # filter thickness in mm

det_mat = 'CsI' # scintillator material
det_density = 4.51 # scintillator density g/cm^3
det_th = 0.33 # scintillator thickness in mm

sample_mats = ['V', 'Al', 'Ti', 'Mg']
sample_radius = 0.5 # sample diameter in mm


ct_info = {
    "Geometry": "Parallel",
    "psize": [0.01, 0.01],  # Width and height in mm
    "rsize": [0.01, 0.01],
    "shape": [50, 512],     # Rows and columns
    "NViews": 64
}

# %% [markdown]
# ## A. Simulate multi-energy dataset using MBIRJAX projector

# %% [markdown]
# ### A01. Ground Truth Source Spectra
# In this tutorial,
# - use spekpy to generate X-ray source spectum.
# - the description of 2 used functions from spekpy is shown below by the help function.

# %%
import spekpy as sp
help(sp.Spek.__init__)
# Out:
# Help on function __init__ in module spekpy.SpekPy:
#
# __init__(self, kvp=None, th=None, dk=None, mu_data_source=None, physics=None, x=None, y=None, z=None, mas=None, brem=None, char=None, obli=None, comment=None, targ=None, shift=None, init_default=True)
#     Constructor method for the Spek class
#
#     SEE THE WIKI PAGES FOR MORE INFO:
#     https://bitbucket.org/spekpy/spekpy_release/wiki/Further_information
#
#     :param float kvp: tube potential [kV] (default: depends on target)
#     :param float th: anode angle [degrees] (default: 12 degrees)
#     :param float dk: energy bin width [keV] (default: 0.5 keV)
#     :param string: mu_data_source (default: depends on physics model)
#         options: ('pene' or 'nist')
#     :param float physics: physics model (default: 'casim')
#         options: ('casim', 'kqp', 'spekpy-v1', 'spekcalc',
#                   'diff', 'uni', 'sim', 'classical')
#     :param float x: displacement from central axis in anode-cathode
#         direction [cm] (default: 0 cm)
#     :param float y: displacement from central axis in orthogonal
#         direction [cm] (default: 0 cm)
#     :param float z: focus-to-detector distance [cm] (default: 100 cm)
#     :param float mas: the tube current-time product [mAs] (default: 1 mAs)
#     :param logical brem: whether bremsstrahlung x rays requested
#         (default: true)
#     :param logical char: whether characteristic x rays requested
#         (default: true)
#     :param logical obli: whether increased oblique paths through filtration
#         are assumed for off axis positions (default: true)
#     :param string comment: any text annotation the user wishes to add
#     :param string targ: the anode target material (default: 'W')
#         options: ('W', 'Mo', or 'Rh')
#     :param float shift: optional fraction of an energy bin to shift the
#         energy bins (useful when matching to measurements) (default: 0.0)

# %%
help(sp.Spek.get_spectrum)
# Out:
# Help on function get_spectrum in module spekpy.SpekPy:
#
# get_spectrum(self, edges=False, flu=True, diff=True, sig=None, addend=False, **kwargs)
#     A method to get the energy and spectrum for the parameters in the
#     current spekpy state
#
#     :param bool edges: Keyword argument to determine whether midbin or edge
#         of bins data are returned
#     :param bool addend: Keyword argument to determine whether a zero
#         end point is added to the spectrum
#     :param bool flu: Whether to return fluence or energy-fluence
#     :param bool diff: Whether to return spectrum differential in energy
#     :param kwargs: Keyword arguments to change parameters that are used for
#         the calculation
#     :return array k: Array with photon energies (mid-bin or edge values)
#         [keV]
#     :return array spk: Array with corresponding photon fluences
#         [Photons cm^-2 keV^-1], [Photons cm^-2] or [Photons cm^-2 keV^1]
#         depending of values of flu and diff inputs

# %%
max_simkV = max(voltage_list)
takeoff_angle = 13

# Define energy bins from 1.5 keV up to (max_simkV - 0.5) keV.
energies = np.linspace(1.5, max_simkV - 0.5, max_simkV-1)

# Initialize an empty list to store the generated source spectra.
gt_src_spec_list = []

for case_i, simkV in enumerate(voltage_list):
    # Generate the X-ray spectrum model with Spekpy for each voltage.
    # kvp is source voltage
    # th is anode angle
    # dk is energy bin size
    # z is focus-to-detector distance [cm], use source-detector distance instead and convert mm to cm.
    # mas is current-time product mA*s
    # char=True requests characteristic x rays.
    s = sp.Spek(kvp=simkV, th=takeoff_angle, dk=1,z=1, mas=mas_list[case_i], char=True)
    
    # Return data at the mid of a bin or the edges of a bin.
    k, phi_k = s.get_spectrum(edges=False)  # Retrieve energy bins and fluence spectrum [Photons cm^-2 keV^-1]
    
    # Adjust the fluence for the detector pixel area.
    phi_k = phi_k * ((ct_info['psize'][0] / 10) * (ct_info['psize'][1] / 10))  # Convert pixel size from cm² to mm²

    # Initialize a zero-filled spectrum array with length max_simkV.
    src_spec = np.zeros(max_simkV-1)
    src_spec[:simkV-1] = phi_k  # Assign spectrum values starting from 1.5 keV

    # Add the processed spectrum for this voltage to the list.
    gt_src_spec_list.append(src_spec)

# Convert the list of source spectra to a numpy array for easy handling.
gt_src_spec_list = np.array(gt_src_spec_list)

# Plot each generated source spectrum.
for src_i, gt_src_spec in enumerate(gt_src_spec_list):
    plt.plot(energies, gt_src_spec, label='%d kV' % voltage_list[src_i])

plt.title('Ground Truth Source Spectra')
plt.xlabel('Energy (keV)')
plt.ylabel('Photons per pixel [$mm^{-2}$ $keV^{-1}$]')
plt.grid()
plt.legend()

# %% [markdown]
# #### A02. Ground Truth Filter Response
# Filter response is defined as
# $$
# f(E) = e^{-\mu(m, E)\cdot t}
# $$
# where $t$ is thickness; $\mu$ is linear attenuation coefficient(LAC), which depends on photon energy and material $m$ formula and density.

# %%
from xcal import get_filter_response
from xcal.chem_consts._periodictabledata import density

# get_filter_response returns a ratio of passing through photons.
# F(E) = e^(-\mu_{mat}(E)*thickness) 
# \mu_{mat}(E) = mac{mat}(E) * density
# where \mu denotes linear attenuation coefficient; mac means mass attenuation coefficient.
gt_fltr = get_filter_response(energies, fltr_mat, density[fltr_mat], fltr_th)

plt.plot(energies, gt_fltr, label='3mm Al')
plt.title('Ground Truth Filter Response')
plt.legend()
plt.xlabel('Energy (keV)')
plt.grid()

# %% [markdown]
# ### A03. Ground Truth Detector Response
#
# Converted energy from a X-ray photon with energy from 1 to 180 keV.
#
# Detector response is defined as
# $$
# D(E) =\frac{\mu_{en}(m, E)}{\mu(m, E)} (1 - e^{-\mu(m, E)\cdot t} )
# $$
# where $t$ is scintillator thickness; $\mu$ is linear attenuation coefficient(LAC), which depends on photon energy $E$ and material $m$ formula and density; $\mu_en$ is linear energy-absorption coefficient(LAC).

# %%
from xcal import get_scintillator_response
from xcal.chem_consts._periodictabledata import density

# get_scintillator_response returns converted energy per photon at energy E.
# D(E) = -\mu_en/\mu * (1-e^(-\mu(E)*thickness))
# \mu(E) = mac(E) * density
# \mu_en(E) = mac_en(E) * density
# where \mu denotes linear attenuation coefficient; mac means mass attenuation coefficient.
# where \mu_en denotes linear energy-absorption coefficient; mac_en means mass energy-absorption coefficient.
gt_det = get_scintillator_response(energies, det_mat, det_density, det_th)

plt.plot(energies, gt_det, label='%.2fmm %s'%(det_th, det_mat))
plt.title('Ground Truth Scintillator Response')
plt.legend()
plt.xlabel('Energy (keV)')
plt.grid()

# %% [markdown]
# ### A04. Linear Attenuation Coefficients of homogenous samples

# %%
from xcal.chem_consts import get_lin_att_c_vs_E
help(get_lin_att_c_vs_E)
# Out:
# Help on function get_lin_att_c_vs_E in module xcal.chem_consts._consts_from_table:
#
# get_lin_att_c_vs_E(density, formula, energy_vector)
#     Calculate the linear attenuation coefficient (mu) as a function of energy,
#     using mass attenuation coefficients from the NIST website:
#     https://physics.nist.gov/PhysRefData/XrayMassCoef/tab3.html.
#
#     Author: Wenrui Li, Purdue University
#     Date: 04/12/2022
#
#     Parameters
#     ----------
#     density : float
#         Density of the material in g/cm^3.
#     formula : str/dict
#         Chemical formula of the compound, either as a string or a dict.
#         For example, "H2O" and {"H": 2, "O": 1} are both acceptable.
#     energy_vector : list/numpy.ndarray
#         Energy (units: keV) list or 1D array for which beta values are calculated.
#
#     Returns
#     -------
#     numpy.ndarray
#         Linear attenuation coefficient values in mm^-1, with the same size as energy_vector.

# %%
# Scanned Homogeneous Rods
# Density for homogenous material is stored in the imported density dictionary
mat_density = [density[formula] for formula in sample_mats]
lac_vs_E_list = [get_lin_att_c_vs_E(den, formula, energies) for den, formula in zip(mat_density, sample_mats)]

# Plot LAC
for lac_vs_E,mat in zip(lac_vs_E_list, sample_mats):
    plt.plot(energies, lac_vs_E, label=mat)
plt.yscale('log')
plt.title(r'Linear Attenuation Coefficient $\mu$ ($mm^{-1}$)')
plt.xlabel('Energy (keV)')
plt.grid()
plt.legend()

# %% [markdown]
# ### A05. GT X-ray System Spectral Responses

# %%
gt_spec_list = [gt_source * gt_fltr  * gt_det for gt_source in gt_src_spec_list]
for spec_i, gt_spec in enumerate(gt_spec_list):
    plt.plot(energies, gt_spec/np.trapezoid(gt_spec,energies), label='%d kV'%voltage_list[spec_i])
plt.legend()
plt.title('Ground Truth: X-ray System Spectral Response')
plt.xlabel('Energy (keV)')
plt.grid()
plt.legend()

# %% [markdown]
# ### A06. Masks for 4 homogenous samples
#
# Obtain a list of mask for each corresponding homogenous sample rod.
# These masks is then used to calculate the forward matrix for the transmission function.

# %%
from xcal._utils import Gen_Circle
help(Gen_Circle.__init__)
# Out:
# Help on function __init__ in module xcal._utils:
#
# __init__(self, canvas_shape, pixel_size)
#     Initialize the Circle class.
#
#     Parameters:
#     canvas_shape (tuple): The shape of the canvas, in pixels.
#     pixel_size (tuple): The size of a pixel, in the same units as the canvas.

# %%
help(Gen_Circle.generate_mask)
# Out:
# Help on function generate_mask in module xcal._utils:
#
# generate_mask(self, radius, center=None)
#     Generate a binary mask for the circle.
#
#     Parameters:
#     radius (int): The radius of the circle, in pixels.
#     center (tuple): The center of the circle.
#
#     Returns:
#     ndarray: A 2D numpy array where points inside the circle are marked as True and points outside are marked as False.

# %%
# Define parameters for 4 cylinders with 0.5mm radius, evenly distributed on a circle with a radius of 1.5mm.
Radius = [sample_radius for _ in range(len(sample_mats))]  # Radius of each cylindrical cross-section in mm
arrange_with_radius = 1.5  # Radius of the circle on which cylinder centers are distributed (in mm)

# Calculate center positions for each cylinder, evenly spaced around the circular arrangement
centers = [[np.sin(rad_angle) * arrange_with_radius, np.cos(rad_angle) * arrange_with_radius]
           for rad_angle in np.linspace(-np.pi / 2, -np.pi / 2 + np.pi * 2, len(sample_mats), endpoint=False)]

# Generate 3D masks for each cylinder
# Obtain a list of mask for each corresponding homogenous sample rod. 
# These masks is then used to calculate the forward matrix for the transmission function.
mask_list = []
for mat_id, mat in enumerate(sample_mats):
    # Initialize a circular mask generator for 2D slices
    # Use the number of column pixels to define a canvas
    circle = Gen_Circle((ct_info["shape"][1], ct_info["shape"][1]), 
                        (ct_info["rsize"][0], ct_info["rsize"][1])) # Image volume size
    # Create a 3D mask array for the current cylinder by repeating the circular 2D mask across slices
    mask_3d = np.array([circle.generate_mask(Radius[mat_id], centers[mat_id]) 
                        for i in range(ct_info["shape"][0])]).transpose((1,2,0))
    mask_list.append(mask_3d)

# Below just for display    
# Initialize the phantom array to hold combined cylinder masks
phantom = np.zeros(mask_list[0].shape)    

# Combine all masks into the phantom, weighted by the linear attenuation coefficients for each material
for mat_id, mat in enumerate(sample_mats):
    phantom += mask_list[mat_id] * np.mean(lac_vs_E_list[mat_id])

# Display a slice of the phantom (e.g., 26th slice) to show cross-sectional circles of cylinders
plt.imshow(phantom[:,:,25], extent=[-2.56, 2.56, -2.56, 2.56], origin='lower')

# Annotate each circle with its corresponding material name
for mat_id, mat in enumerate(sample_mats):
    plt.text(centers[mat_id][1], centers[mat_id][0], mat, fontsize=15, ha='right', color='red')
plt.title('Phantom: 4 homogenous samples')
# Out:
# Text(0.5, 1.0, 'Phantom: 4 homogenous samples')

# %% [markdown]
# ### A07. Setup forward projector with MBIRJAX

# %%
import time
import mbirjax

class fw_projector:
    def __init__(self, angles, num_rows, num_channels, delta_pixel=1):
        """

        Parameters
        ----------
        energies
        N_views
        psize
        xcenter
        arange
        """
        self.angles = angles
        self.num_rows = num_rows
        self.num_channels = num_channels
        self.delta_pixel = delta_pixel
        self.sinogram_shape = (len(angles), self.num_rows, self.num_channels)

    def forward(self, mask):
        """

        Parameters
        ----------
        mask : numpy.ndarray
            3D mask for pure solid object.

        Returns
        -------
        lai : numpy.ndarray
            Linear attenuation integral, of size M measurement * N energy bins.

        """

        ct_model_for_generation = mbirjax.ParallelBeamModel(self.sinogram_shape, self.angles)
        # Print out model parameters
        ct_model_for_generation.print_params()
        projections = ct_model_for_generation.forward_project(mask) * self.delta_pixel

        return projections
    
angles = np.linspace(-np.pi/2, np.pi/2, ct_info['NViews'], endpoint=False)
projector = fw_projector(angles, num_rows=ct_info["shape"][0], num_channels=ct_info["shape"][1], delta_pixel=ct_info["psize"][0])

# %% [markdown]
# ### A08. Calculate Attenuation Matrix
# We let $ \mu_k(E) $ denote the LAC of the $k^\text{th}$ homogeneous sample at energy $E$, and let $L_{k, i}$ denote the path length through the $k^{th}$ material at projection $i$ for samples $k=0, \ldots, K-1$.
# The attenuation matrix is calculated as below,
# $$
# A(E) = \exp \left\{-\sum_{k=0}^{K-1} \mu_k(E) L_{k, i}\right\}
# $$
#
# Notice that $L_{k, i}$ is calcuated by projecting $k^\text{th}$ mask in mask_list with a projector defined in A07.
# One should create the “projector” object in a similar way defined in A07 if use CT projector other than MBIRJAX.

# %%
from xcal import calc_forward_matrix
spec_F = calc_forward_matrix(mask_list, lac_vs_E_list, projector)
# Out:
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# /Users/damonli/anaconda3/envs/xcal/lib/python3.10/site-packages/mbirjax/tomography_model.py:229: UserWarning: CPU memory may be insufficient for this problem.  This may lead to a fatal error.
#   warnings.warn('CPU memory may be insufficient for this problem.  This may lead to a fatal error.')
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----

# %% [markdown]
# ### A09. Simulate Transmission Data

# %%
trans_list = []
for case_i, gt_spec in zip(np.arange(len(gt_spec_list)), gt_spec_list):
    # Obtain the converted energy, which is proportional to the detected visible light photons by the camera.
    # gt_spec is the converted energy without an object.
    # Notice that, trapezoid does the energy integration.
    trans = np.trapezoid(spec_F * gt_spec, energies, axis=-1) # Object scan
    trans_0 = np.trapezoid(gt_spec, energies, axis=-1) # Air scan value
    # Add poisson noise.
    # The noise level can be adjusted by changing the mas, the current-time product in the beginning of this tutorial.
    trans_noise = np.random.poisson(trans).astype(np.float32)
    trans_noise /= trans_0

    # Store noisy transmission data.
    trans_list.append(trans_noise)

# %%
for case_i, gt_spec in enumerate(gt_spec_list):
    plt.plot(trans_list[case_i][3, 25], label=f'{voltage_list[case_i]} keV')
plt.legend()
plt.grid()
plt.title('Simulated Transmission Data')
# Out:
# Text(0.5, 1.0, 'Simulated Transmission Data')

# %% [markdown]
# ## B. Spectral Calibration

# %% [markdown]
# ### B01. FBP Reconstruction using MBIRJAX
# Reconstructing one CT scan using MBIR.

# %%
# Reconstructing one CT scan using MBIR.
sino = -np.log(trans_list[-1]).astype(np.float32)
sino = np.ascontiguousarray(sino, dtype=np.float32) # shape is numAngles, numRows, numCols

startTime = time.time()
sinogram_shape = (len(angles), ct_info["shape"][0], ct_info["shape"][1])
ct_model_for_recon = mbirjax.ParallelBeamModel(sinogram_shape, angles)
sharpness = 1.0
ct_model_for_recon.set_params(sharpness=sharpness)
ct_model_for_recon.set_params(positivity_flag=True)
recon, recon_params = ct_model_for_recon.recon(sino, weights=None, max_iterations=20) # shape is numZ, numY, numX
recon = recon/ct_info["psize"][0] # convert ALU^-1 to mm^-1
recon = recon.transpose((2,0,1))
print('Reconstruction Elapsed Time: ' + str(time.time()-startTime))
# Out:
# GPU used for: none
# Estimated GPU memory required = 0.000 GB, available = 0.000 GB
# Estimated CPU memory required = 1.111 GB, available = 7.030 GB
# Starting direct recon for initial reconstruction
# Initializing error sinogram
# Computing Hessian diagonal
# Starting VCD iterations
#
# After iteration 0 of a max of 20: Pct change=40.0798, Forward loss=3.2338
# Relative step size (alpha)=1.15, Error sino RMSE=0.0375
# Number subsets = 1
#
# After iteration 1 of a max of 20: Pct change=27.0722, Forward loss=1.1293
# Relative step size (alpha)=1.03, Error sino RMSE=0.0131
# Number subsets = 16
#
# After iteration 2 of a max of 20: Pct change=8.4697, Forward loss=1.0917
# Relative step size (alpha)=1.50, Error sino RMSE=0.0127
# Number subsets = 64
#
# After iteration 3 of a max of 20: Pct change=4.2072, Forward loss=1.0835
# Relative step size (alpha)=1.50, Error sino RMSE=0.0126
# Number subsets = 128
#
# After iteration 4 of a max of 20: Pct change=2.2618, Forward loss=1.0805
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 5 of a max of 20: Pct change=1.4496, Forward loss=1.0787
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 6 of a max of 20: Pct change=1.0661, Forward loss=1.0776
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 7 of a max of 20: Pct change=0.8406, Forward loss=1.0766
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 8 of a max of 20: Pct change=0.6954, Forward loss=1.0760
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 9 of a max of 20: Pct change=0.5921, Forward loss=1.0754
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 10 of a max of 20: Pct change=0.5144, Forward loss=1.0750
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 11 of a max of 20: Pct change=0.4571, Forward loss=1.0745
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 12 of a max of 20: Pct change=0.4119, Forward loss=1.0743
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 13 of a max of 20: Pct change=0.3778, Forward loss=1.0740
# Relative step size (alpha)=1.50, Error sino RMSE=0.0125
# Number subsets = 128
#
# After iteration 14 of a max of 20: Pct change=0.3497, Forward loss=1.0737
# Relative step size (alpha)=1.50, Error sino RMSE=0.0124
# Number subsets = 128
#
# After iteration 15 of a max of 20: Pct change=0.3286, Forward loss=1.0735
# Relative step size (alpha)=1.50, Error sino RMSE=0.0124
# Number subsets = 128
#
# After iteration 16 of a max of 20: Pct change=0.3132, Forward loss=1.0734
# Relative step size (alpha)=1.50, Error sino RMSE=0.0124
# Number subsets = 128
#
# After iteration 17 of a max of 20: Pct change=0.3006, Forward loss=1.0732
# Relative step size (alpha)=1.50, Error sino RMSE=0.0124
# Number subsets = 128
#
# After iteration 18 of a max of 20: Pct change=0.2929, Forward loss=1.0731
# Relative step size (alpha)=1.50, Error sino RMSE=0.0124
# Number subsets = 128
#
# After iteration 19 of a max of 20: Pct change=0.2878, Forward loss=1.0730
# Relative step size (alpha)=1.50, Error sino RMSE=0.0124
# Number subsets = 128
# Reconstruction Elapsed Time: 68.87098789215088

# %%
plt.imshow(recon[25])
plt.colorbar()
plt.title('Reconstruction')
# Out:
# Text(0.5, 1.0, 'Reconstruction')

# %% [markdown]
# ### B02. Circle Detection (Optional)
# The circle detection provides a coarse bounding box for object segmentation.
# One can manually set the bounding box for the object segmentation, if the sample is not cylindrical.
#
# Below is an example to use detect_hough_circles to detect circles on the $25^{th}$ slice of the reconstruction.

# %%
from xcal.phantom import detect_hough_circles

# %%
help(detect_hough_circles)
# Out:
# Help on function detect_hough_circles in module xcal.phantom:
#
# detect_hough_circles(phantom, radius_range=None, vmin=0, vmax=None, min_dist=100, HoughCircles_params1=300, HoughCircles_params2=1)
#     Detects circles in an image using the Hough Circle Transform.
#
#     Args:
#         phantom (numpy.ndarray): The 2D image to detect circles in.
#         radius_range (list of int, optional): The minimum and maximum radius of
#             circles to detect. Defaults to a range based on the image size.
#         vmin (int, optional): Minimum value for clipping the image before
#             detection. Defaults to 0.
#         vmax (int, optional): Maximum value for clipping the image before
#             detection. If None, the 90th percentile of the image is used.
#             Defaults to None.
#         min_dist (int, optional): Minimum distance between the centers of the
#             detected circles. If too small, multiple neighbor circles may be
#             falsely detected in addition to a true one. If too large, some
#             circles may be missed. Defaults to 100.
#         HoughCircles_params1 (float, optional): Upper threshold for the internal edge detection.
#         HoughCircles_params2 (float, optional): Threshold for center detection, which influences the detection sensitivity. Large param2 leads to fewer detected circles.
#
#     Returns:
#         numpy.ndarray: An array of detected circles, each represented by the
#             center coordinates (x, y) and radius. Returns an empty array if no
#             circles are detected.

# %%
from matplotlib.patches import Circle
import math

plt.imshow(recon[25],origin='lower')
plt.colorbar()
# Get the current axes.
ax = plt.gca()
circles = detect_hough_circles(recon[25], 
                               radius_range=(45, 55), 
                               vmin=0.00, vmax=0.1, 
                               min_dist=200,
                               HoughCircles_params2=10)

# Below is for display and sort the detected circles.
# x is horizontal axis, y is vertical axis. 
circles_values = np.array([np.mean(recon[25][int(y-r):int(y+r),int(x-r):int(x+r)]) for x,y,r in circles])
# Sort `circles` based on the order in `circles_values`
circles = [cir for _, cir in sorted(zip(circles_values, circles))]
# Rearrange based on material ['V', 'Al', 'Ti', 'Mg'] 
circles = [circles[i] for i in [3,1,2,0]]

# Create and add circles to the plot.
for x, y, radius in circles:
    circle = Circle((x, y), radius, color='red', fill=False)
    ax.add_patch(circle)

# Optionally set the aspect of the plot to be equal.
# This makes sure that the circles are not skewed.
ax.set_aspect('equal')
plt.title('Circle Detection')
# Show the plot with the circles.
plt.show()

# %% [markdown]
# ### B03. Segment Object to get 3D Mask
#
# segment_object is a function to segment one sample from background.

# %%
from xcal.phantom import segment_object

# %%
help(segment_object)
# Out:
# Help on function segment_object in module xcal.phantom:
#
# segment_object(phantom, vmin, vmax, canny_sigma, roi_radius=None, bbox=None)
#     Segments an object within a given region of interest (ROI) or bounding box in an image.
#
#     This function creates a segmentation mask for an object in an image. The image values
#     are clipped and normalized based on provided minimum and maximum values. Canny edge
#     detection is then applied to the normalized image. The edges are filled to create a
#     binary mask that segments the object.
#
#     Args:
#         phantom (np.array): The input image to segment.
#         vmin (float): The minimum value for clipping the image.
#         vmax (float): The maximum value for clipping the image.
#         canny_sigma (float): The standard deviation for the Gaussian filter used in
#                              Canny edge detection.
#         roi_radius (int, optional): The radius of the circular region of interest. If not
#                                     provided, it defaults to half the image size.
#         bbox (tuple of int, optional): The bounding box within which to perform segmentation,
#                                        specified as (r_min, c_min, r_max, c_max). If not
#                                        provided, the entire image is used.
#
#     Returns:
#         np.array: A binary segmentation mask of the object.

# %%
est_mask_list = []
bbox_half_size = int(np.mean([cir[2] for cir in circles])*1.1)
# Manually set the threshold based on above plot.
vmin_list = [0.02,0.01,0.2,0.01]
vmax_list = [0.7,0.02,0.4,0.02]
# Loop through each slice to get 3D mask.
for vi,cir in enumerate(circles):
    xcenter, ycenter, r = cir
    # Segment object with 3D mask
    # Set different vmin and vmax for different samples.
    # Set bbox to restrict a box region for object segmentation.
    est_mask = [segment_object(
        recon[i], 
        vmin_list[vi], 
        vmax_list[vi], 
        10, # Canny sigma in canny edge detection. Larger value is more possible to connect to a line.
        roi_radius=None,
        bbox=(
            int(ycenter - bbox_half_size),
            int(xcenter - bbox_half_size),
            int(ycenter + bbox_half_size),
            int(xcenter + bbox_half_size)
        )) for i in range(len(recon))]
    est_mask_list.append(np.array(est_mask))

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 8))

for j in range(len(est_mask_list)):
    ax = axs.flat[j]
    est_mask = est_mask_list[j]
    gtmask = mask_list[j]
    # Display the image or the difference image.
#     ax.imshow(est_mask[25],origin='lower')
    ax.imshow(est_mask[25].astype('float32')-gtmask[:,:,25].astype('float32'),vmin=-1,vmax=1,origin='lower')
# Adjust the layout
plt.tight_layout()
plt.title('Difference between estimated masks and GT mask.')
plt.show()

# %%
# Define colors for each mask
colors = ['b', 'g', 'r', 'm']  # Blue, Green, Red, Magenta for each est_mask

# Plot the 3D masks using a scatter plot with different colors
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

for i, est_mask in enumerate(est_mask_list):
    # Get the coordinates of the points where the mask is 1
    z, y, x = np.where(est_mask == 1)
    ax.scatter(x, y, z, color=colors[i], marker='o', s=1, alpha=0.7, label=sample_mats[i])

# Set labels and title
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("Estimated 3D Binary Mask Visualization with Different Colors")
plt.legend()
plt.show()

# %% [markdown]
# ### B04. Calculate Forward Matrix with Estimated 3D Masks

# %%
# Only use 8 different views for spectral calibration
NViews_For_MBSC = 8
projector2 = fw_projector(angles[::ct_info["NViews"]//NViews_For_MBSC], num_rows=ct_info["shape"][0], num_channels=ct_info["shape"][1], delta_pixel=ct_info["psize"][0])

# %%
for i in range(len(est_mask_list)):
    est_mask_list[i] = est_mask_list[i].transpose((1,2,0))
est_spec_F = calc_forward_matrix(est_mask_list, lac_vs_E_list, projector2)
# Out:
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----

# %% [markdown]
# ### B05. X-ray System Model Configuration

# %%
from xcal.models import Reflection_Source, Filter, Scintillator
from xcal.defs import Material

# %%
# Use Spekpy to generate a source spectra dictionary.
takeoff_angles = np.linspace(5,45,11)
src_spec_list = []
for case_i,simkV in enumerate(voltage_list):
    for ta in takeoff_angles:
        # Generate the X-ray spectrum model with Spekpy for each voltage.
        s = sp.Spek(kvp=simkV, th=ta, dk=1,z=1, mas=mas_list[case_i], char=True)
        k, phi_k = s.get_spectrum(edges=False)  # Retrieve energy bins and fluence spectrum [Photons cm^-2 keV^-1]

        # Adjust the fluence for the detector pixel area.
        phi_k = phi_k * ((ct_info['psize'][0] / 10) * (ct_info['psize'][1] / 10))  # Convert pixel size from mm² to cm²

        # Initialize a zero-filled spectrum array with length max_simkV.
        src_spec = np.zeros(max_simkV-1)
        src_spec[:simkV-1] = phi_k  # Assign spectrum values starting from 1.5 keV

        # Add the processed spectrum for this voltage to the list.
        src_spec_list.append(src_spec)

src_spec_list = np.array(src_spec_list)
src_spec_list = src_spec_list.reshape((len(voltage_list),len(takeoff_angles),-1))

# %%
# Configure the Reflection Source Model
# Reflection_Source is a PyTorch module that supports gradient descent.
# Reflection_Source initializes with specified source voltage and takeoff angle.
# The set_src_spec_list method assigns a dictionary for each source configuration.
# Reflection_Source.forward() provides interpolated dictionary components for each source.

# Source voltage is set to be fixed by setting minbound and maxbound to None.
# Takeoff angle is estimated in range [5,45] with inital value 25 degree.
sources = [Reflection_Source(voltage=(voltage, None, None), takeoff_angle=(25, 5, 45), single_takeoff_angle=True)
           for voltage in voltage_list]
# Assigning the dictionaries for each source.
for src_i, source in enumerate(sources):
    source.set_src_spec_list(energies, src_spec_list, voltage_list, takeoff_angles)

# %%
# Both the filter and scintillator contain discrete and continuous parameters.
# All continuous parameters are defined using a tuple format with an initial value, minimum bound, and maximum bound.
# Any other format is recognized as a discrete parameter.
# Concatenating all component instances (sources, filters, scintillator) into a list, called spectral configuration like [source, filter_1, scintillator_1], 
# allows the Estimator defined in B07 to recognize all parameters, whether discrete or continuous for a scan.
# The spec_models collects all spectral configuration. Each spectral configuration corresponding to a scan.
# The Estimator will then automatically determine all possible combinations for the discrete parameters and optimize the continous parameters.


# Configure Filter Model
# Knowns: Use one filter for both scans.
# Possible filter materials: Al and Cu.
psb_fltr_mat = [Material(formula='Al', density=2.702), 
                Material(formula='Cu', density=8.92)]
filter_1 = Filter(psb_fltr_mat, thickness=(5, 0, 10))

# Configure Scintillator Model
# Knowns: Use one scintillator for both scans.
# Possible scintillator materials
scint_params_list = [
    {'formula': 'CsI', 'density': 4.51},
    {'formula': 'Gd3Al2Ga3O12', 'density': 6.63},
    {'formula': 'Lu3Al5O12', 'density': 6.73},
    {'formula': 'CdWO4', 'density': 7.9},
    {'formula': 'Y3Al5O12', 'density': 4.56},
    {'formula': 'Bi4Ge3O12', 'density': 7.13},
    {'formula': 'Gd2O2S', 'density': 7.32}
]
psb_scint_mat = [Material(formula=scint_p['formula'], density=scint_p['density']) for scint_p in scint_params_list]
scintillator_1 = Scintillator(materials=psb_scint_mat, thickness=(0.25, 0.01, 0.5))

# For each scan using a different source voltage, we define a different total spectral model.
# Each spectral model is a list containing source, filters, and scintillator models. 
# Allow filter_1, ..., filter_n.
spec_models = [[source, filter_1, scintillator_1] for source in sources]

# %% [markdown]
# ### B06. Spectral Calibration with Simulated Multi-Energy Data

# %%
trans_list[0].shape
# Out:
# (64, 50, 512)

# %%
# Build Training Set
# Use first 8 views and center 2 slices.
train_rads = [trans[::ct_info["NViews"]//NViews_For_MBSC,10:-10:10] for trans in trans_list]

# Assume a same forward matrix for different scans at different voltages.
forward_matrices = [est_spec_F[:,10:-10:10] for i in range(len(voltage_list))]

print("Training Measurement Shape: \n", train_rads[0].shape,train_rads[1].shape,train_rads[2].shape)
print("Training Forward Matrix Shape: \n",forward_matrices[0].shape,forward_matrices[1].shape,forward_matrices[2].shape)
# Out:
# Training Measurement Shape:
#  (8, 3, 512) (8, 3, 512) (8, 3, 512)
# Training Forward Matrix Shape:
#  (8, 3, 512, 179) (8, 3, 512, 179) (8, 3, 512, 179)

# %%
from xcal.estimate import Estimate

learning_rate = 0.01 # 0.01 for NNAT_LBFGS and 0.001 for Adam
max_iterations = 5000 # 5000 ~ 10000 would be enough
stop_threshold = 1e-6
optimizer_type = 'NNAT_LBFGS' # Can also use Adam.

Estimator = Estimate(energies)
# For each scan, add data and calculated forward matrix to Estimator.
for nrad, forward_matrix, concatenate_models in zip(train_rads, forward_matrices, spec_models):
    Estimator.add_data(nrad, forward_matrix, concatenate_models, weight=None)

# Fit data
Estimator.fit(learning_rate=learning_rate,
              max_iterations=max_iterations,
              stop_threshold=stop_threshold,
              optimizer_type=optimizer_type,
              loss_type='transmission',
              logpath=None,
              num_processes=1) # Parallel computing for multiple cpus.
# Out:
# Number of cases for different discrete parameters: 14
# 2025-05-08 00:28:48,980  - Start Estimation.
# 2025-05-08 00:28:49,027  - Initial cost: 1.703223e-03
# 2025-05-08 00:28:49,498  - Iteration: 5
# 2025-05-08 00:28:49,608  - Cost: 0.0007455818704329431
# 2025-05-08 00:28:49,608  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:49,608  - Filter_2_thickness: 4.209051609039307
# 2025-05-08 00:28:49,608  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:49,608  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:49,609  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:49,609  - Reflection_Source_takeoff_angle: 25.242326736450195
# 2025-05-08 00:28:49,609  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:49,609  - Scintillator_2_thickness: 0.2537390887737274
# 2025-05-08 00:28:49,609  -
# 2025-05-08 00:28:50,030  - Iteration: 10
# 2025-05-08 00:28:50,132  - Cost: 0.0006081174942664802
# 2025-05-08 00:28:50,132  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:50,132  - Filter_2_thickness: 3.9177892208099365
# 2025-05-08 00:28:50,132  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:50,132  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:50,132  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:50,132  - Reflection_Source_takeoff_angle: 24.911514282226562
# 2025-05-08 00:28:50,132  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:50,132  - Scintillator_2_thickness: 0.2636187672615051
# 2025-05-08 00:28:50,132  -
# 2025-05-08 00:28:50,591  - Iteration: 15
# 2025-05-08 00:28:50,703  - Cost: 0.0005602497258223593
# 2025-05-08 00:28:50,704  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:50,704  - Filter_2_thickness: 3.727994918823242
# 2025-05-08 00:28:50,704  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:50,704  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:50,704  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:50,704  - Reflection_Source_takeoff_angle: 24.245037078857422
# 2025-05-08 00:28:50,704  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:50,704  - Scintillator_2_thickness: 0.27932775020599365
# 2025-05-08 00:28:50,704  -
# 2025-05-08 00:28:51,135  - Iteration: 20
# 2025-05-08 00:28:51,238  - Cost: 0.0004966841079294682
# 2025-05-08 00:28:51,238  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:51,238  - Filter_2_thickness: 3.4969635009765625
# 2025-05-08 00:28:51,238  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:51,238  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:51,238  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:51,238  - Reflection_Source_takeoff_angle: 22.303972244262695
# 2025-05-08 00:28:51,238  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:51,238  - Scintillator_2_thickness: 0.3187955319881439
# 2025-05-08 00:28:51,238  -
# 2025-05-08 00:28:51,641  - Iteration: 25
# 2025-05-08 00:28:51,747  - Cost: 0.00044613826321437955
# 2025-05-08 00:28:51,747  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:51,747  - Filter_2_thickness: 3.340953826904297
# 2025-05-08 00:28:51,747  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:51,747  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:51,747  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:51,747  - Reflection_Source_takeoff_angle: 19.488811492919922
# 2025-05-08 00:28:51,747  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:51,747  - Scintillator_2_thickness: 0.3566802740097046
# 2025-05-08 00:28:51,747  -
# 2025-05-08 00:28:52,175  - Iteration: 30
# 2025-05-08 00:28:52,277  - Cost: 0.0004351969691924751
# 2025-05-08 00:28:52,278  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:52,278  - Filter_2_thickness: 3.2347331047058105
# 2025-05-08 00:28:52,278  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:52,278  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:52,278  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:52,278  - Reflection_Source_takeoff_angle: 17.771625518798828
# 2025-05-08 00:28:52,278  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:52,278  - Scintillator_2_thickness: 0.37260666489601135
# 2025-05-08 00:28:52,278  -
# 2025-05-08 00:28:52,633  - Iteration: 35
# 2025-05-08 00:28:52,738  - Cost: 0.0004336657584644854
# 2025-05-08 00:28:52,738  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:52,738  - Filter_2_thickness: 3.2005372047424316
# 2025-05-08 00:28:52,738  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:52,738  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:52,738  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:52,738  - Reflection_Source_takeoff_angle: 17.153831481933594
# 2025-05-08 00:28:52,738  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:52,738  - Scintillator_2_thickness: 0.37657684087753296
# 2025-05-08 00:28:52,738  -
# 2025-05-08 00:28:53,157  - Iteration: 40
# 2025-05-08 00:28:53,260  - Cost: 0.00043324491707608104
# 2025-05-08 00:28:53,260  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:53,260  - Filter_2_thickness: 3.177523612976074
# 2025-05-08 00:28:53,260  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:53,260  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:53,260  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:53,260  - Reflection_Source_takeoff_angle: 16.729490280151367
# 2025-05-08 00:28:53,260  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:53,260  - Scintillator_2_thickness: 0.3776194453239441
# 2025-05-08 00:28:53,260  -
# 2025-05-08 00:28:53,658  - Iteration: 45
# 2025-05-08 00:28:53,760  - Cost: 0.00043310748878866434
# 2025-05-08 00:28:53,761  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:53,761  - Filter_2_thickness: 3.163323163986206
# 2025-05-08 00:28:53,761  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:53,761  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:53,761  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:53,761  - Reflection_Source_takeoff_angle: 16.410255432128906
# 2025-05-08 00:28:53,761  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:53,761  - Scintillator_2_thickness: 0.37643101811408997
# 2025-05-08 00:28:53,761  -
# 2025-05-08 00:28:54,178  - Iteration: 50
# 2025-05-08 00:28:54,281  - Cost: 0.00043292742338962853
# 2025-05-08 00:28:54,281  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:54,281  - Filter_2_thickness: 3.14009428024292
# 2025-05-08 00:28:54,281  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:54,281  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:54,281  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:54,281  - Reflection_Source_takeoff_angle: 15.832799911499023
# 2025-05-08 00:28:54,281  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:54,281  - Scintillator_2_thickness: 0.37063178420066833
# 2025-05-08 00:28:54,281  -
# 2025-05-08 00:28:54,681  - Iteration: 55
# 2025-05-08 00:28:54,784  - Cost: 0.0004326337075326592
# 2025-05-08 00:28:54,784  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:54,785  - Filter_2_thickness: 3.11431884765625
# 2025-05-08 00:28:54,785  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:54,785  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:54,785  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:54,785  - Reflection_Source_takeoff_angle: 15.042609214782715
# 2025-05-08 00:28:54,785  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:54,785  - Scintillator_2_thickness: 0.35671427845954895
# 2025-05-08 00:28:54,785  -
# 2025-05-08 00:28:55,198  - Iteration: 60
# 2025-05-08 00:28:55,232  - Cost: 0.00043255058699287474
# 2025-05-08 00:28:55,232  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:55,232  - Filter_2_thickness: 3.104757308959961
# 2025-05-08 00:28:55,232  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:55,232  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:55,232  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:55,232  - Reflection_Source_takeoff_angle: 14.66220760345459
# 2025-05-08 00:28:55,232  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:55,232  - Scintillator_2_thickness: 0.3493652939796448
# 2025-05-08 00:28:55,232  -
# 2025-05-08 00:28:55,647  - Iteration: 65
# 2025-05-08 00:28:55,750  - Cost: 0.00043252858449704945
# 2025-05-08 00:28:55,750  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:55,750  - Filter_2_thickness: 3.0987730026245117
# 2025-05-08 00:28:55,750  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:55,750  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:55,750  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:55,750  - Reflection_Source_takeoff_angle: 14.437764167785645
# 2025-05-08 00:28:55,750  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:55,750  - Scintillator_2_thickness: 0.34509530663490295
# 2025-05-08 00:28:55,750  -
# 2025-05-08 00:28:56,150  - Iteration: 70
# 2025-05-08 00:28:56,252  - Cost: 0.00043252500472590327
# 2025-05-08 00:28:56,253  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:56,253  - Filter_2_thickness: 3.0961835384368896
# 2025-05-08 00:28:56,253  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:56,253  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:56,253  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:56,253  - Reflection_Source_takeoff_angle: 14.344030380249023
# 2025-05-08 00:28:56,253  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:56,253  - Scintillator_2_thickness: 0.34339115023612976
# 2025-05-08 00:28:56,253  -
# 2025-05-08 00:28:57,974  - Stopping at epoch 71 because updates are too small.
# 2025-05-08 00:28:57,974  - Cost: 0.00043252500472590327
# 2025-05-08 00:28:57,974  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:57,974  - Filter_2_thickness: 3.0961835384368896
# 2025-05-08 00:28:57,974  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:57,974  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:57,974  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:57,975  - Reflection_Source_takeoff_angle: 14.34403133392334
# 2025-05-08 00:28:57,975  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:28:57,975  - Scintillator_2_thickness: 0.3433912396430969
# 2025-05-08 00:28:57,975  -
# 2025-05-08 00:28:57,978  - Start Estimation.
# 2025-05-08 00:28:58,006  - Initial cost: 2.651560e-03
# 2025-05-08 00:28:58,476  - Iteration: 5
# 2025-05-08 00:28:58,585  - Cost: 0.0023608016781508923
# 2025-05-08 00:28:58,585  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:58,585  - Filter_2_thickness: 4.548300743103027
# 2025-05-08 00:28:58,585  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:58,585  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:58,585  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:58,585  - Reflection_Source_takeoff_angle: 24.29110336303711
# 2025-05-08 00:28:58,585  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-08 00:28:58,585  - Scintillator_2_thickness: 0.2454274743795395
# 2025-05-08 00:28:58,585  -
# 2025-05-08 00:28:59,019  - Iteration: 10
# 2025-05-08 00:28:59,128  - Cost: 0.0021719259675592184
# 2025-05-08 00:28:59,128  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:28:59,128  - Filter_2_thickness: 4.048912525177002
# 2025-05-08 00:28:59,128  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:28:59,128  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:28:59,128  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:28:59,128  - Reflection_Source_takeoff_angle: 20.758127212524414
# 2025-05-08 00:28:59,128  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-08 00:28:59,128  - Scintillator_2_thickness: 0.24118547141551971
# 2025-05-08 00:28:59,128  -
# 2025-05-08 00:29:01,063  - Stopping at epoch 12 because updates are too small.
# 2025-05-08 00:29:01,063  - Cost: 0.00210010027512908
# 2025-05-08 00:29:01,063  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:01,063  - Filter_2_thickness: 3.85123872756958
# 2025-05-08 00:29:01,063  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:01,063  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:01,063  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:01,063  - Reflection_Source_takeoff_angle: 18.899555206298828
# 2025-05-08 00:29:01,063  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-08 00:29:01,063  - Scintillator_2_thickness: 0.2396356612443924
# 2025-05-08 00:29:01,063  -
# 2025-05-08 00:29:01,066  - Start Estimation.
# 2025-05-08 00:29:01,094  - Initial cost: 3.248796e-03
# 2025-05-08 00:29:01,552  - Iteration: 5
# 2025-05-08 00:29:01,656  - Cost: 0.002954070456326008
# 2025-05-08 00:29:01,656  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:01,656  - Filter_2_thickness: 4.443892478942871
# 2025-05-08 00:29:01,656  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:01,656  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:01,656  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:01,656  - Reflection_Source_takeoff_angle: 23.815452575683594
# 2025-05-08 00:29:01,656  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-08 00:29:01,656  - Scintillator_2_thickness: 0.25909924507141113
# 2025-05-08 00:29:01,656  -
# 2025-05-08 00:29:02,076  - Iteration: 10
# 2025-05-08 00:29:02,182  - Cost: 0.0024804496206343174
# 2025-05-08 00:29:02,182  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:02,182  - Filter_2_thickness: 3.257288932800293
# 2025-05-08 00:29:02,182  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:02,182  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:02,182  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:02,182  - Reflection_Source_takeoff_angle: 17.20738410949707
# 2025-05-08 00:29:02,182  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-08 00:29:02,182  - Scintillator_2_thickness: 0.3161897361278534
# 2025-05-08 00:29:02,182  -
# 2025-05-08 00:29:04,132  - Stopping at epoch 13 because updates are too small.
# 2025-05-08 00:29:04,132  - Cost: 0.0021667219698429108
# 2025-05-08 00:29:04,132  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:04,132  - Filter_2_thickness: 2.504495620727539
# 2025-05-08 00:29:04,132  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:04,132  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:04,132  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:04,132  - Reflection_Source_takeoff_angle: 11.66817569732666
# 2025-05-08 00:29:04,132  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-08 00:29:04,132  - Scintillator_2_thickness: 0.3606076240539551
# 2025-05-08 00:29:04,132  -
# 2025-05-08 00:29:04,135  - Start Estimation.
# 2025-05-08 00:29:04,164  - Initial cost: 3.215275e-03
# 2025-05-08 00:29:04,624  - Iteration: 5
# 2025-05-08 00:29:04,729  - Cost: 0.0014309813268482685
# 2025-05-08 00:29:04,729  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:04,729  - Filter_2_thickness: 3.79514479637146
# 2025-05-08 00:29:04,729  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:04,729  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:04,729  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:04,729  - Reflection_Source_takeoff_angle: 24.986431121826172
# 2025-05-08 00:29:04,729  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:04,729  - Scintillator_2_thickness: 0.26354673504829407
# 2025-05-08 00:29:04,729  -
# 2025-05-08 00:29:05,156  - Iteration: 10
# 2025-05-08 00:29:05,261  - Cost: 0.001056703389622271
# 2025-05-08 00:29:05,261  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:05,261  - Filter_2_thickness: 3.2265496253967285
# 2025-05-08 00:29:05,261  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:05,261  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:05,261  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:05,261  - Reflection_Source_takeoff_angle: 23.968917846679688
# 2025-05-08 00:29:05,261  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:05,261  - Scintillator_2_thickness: 0.2972632348537445
# 2025-05-08 00:29:05,261  -
# 2025-05-08 00:29:05,686  - Iteration: 15
# 2025-05-08 00:29:05,791  - Cost: 0.0008211572421714664
# 2025-05-08 00:29:05,791  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:05,791  - Filter_2_thickness: 2.8145647048950195
# 2025-05-08 00:29:05,791  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:05,791  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:05,791  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:05,791  - Reflection_Source_takeoff_angle: 21.799339294433594
# 2025-05-08 00:29:05,791  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:05,791  - Scintillator_2_thickness: 0.3485754430294037
# 2025-05-08 00:29:05,791  -
# 2025-05-08 00:29:06,217  - Iteration: 20
# 2025-05-08 00:29:06,322  - Cost: 0.0005532251670956612
# 2025-05-08 00:29:06,322  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:06,322  - Filter_2_thickness: 2.4889602661132812
# 2025-05-08 00:29:06,322  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:06,322  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:06,322  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:06,322  - Reflection_Source_takeoff_angle: 16.424753189086914
# 2025-05-08 00:29:06,322  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:06,322  - Scintillator_2_thickness: 0.41568872332572937
# 2025-05-08 00:29:06,322  -
# 2025-05-08 00:29:06,677  - Iteration: 25
# 2025-05-08 00:29:06,783  - Cost: 0.0005042686825618148
# 2025-05-08 00:29:06,783  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:06,783  - Filter_2_thickness: 2.3543858528137207
# 2025-05-08 00:29:06,783  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:06,783  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:06,783  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:06,783  - Reflection_Source_takeoff_angle: 13.898200035095215
# 2025-05-08 00:29:06,783  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:06,783  - Scintillator_2_thickness: 0.43728184700012207
# 2025-05-08 00:29:06,783  -
# 2025-05-08 00:29:07,209  - Iteration: 30
# 2025-05-08 00:29:07,315  - Cost: 0.0004949342692270875
# 2025-05-08 00:29:07,315  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:07,315  - Filter_2_thickness: 2.2978909015655518
# 2025-05-08 00:29:07,315  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:07,315  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:07,315  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:07,315  - Reflection_Source_takeoff_angle: 12.887067794799805
# 2025-05-08 00:29:07,315  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:07,315  - Scintillator_2_thickness: 0.4477367103099823
# 2025-05-08 00:29:07,315  -
# 2025-05-08 00:29:07,745  - Iteration: 35
# 2025-05-08 00:29:07,854  - Cost: 0.0004927492700517178
# 2025-05-08 00:29:07,854  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:07,854  - Filter_2_thickness: 2.2789368629455566
# 2025-05-08 00:29:07,854  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:07,854  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:07,854  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:07,854  - Reflection_Source_takeoff_angle: 12.60804271697998
# 2025-05-08 00:29:07,854  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:07,854  - Scintillator_2_thickness: 0.45583298802375793
# 2025-05-08 00:29:07,854  -
# 2025-05-08 00:29:08,217  - Iteration: 40
# 2025-05-08 00:29:08,322  - Cost: 0.0004916234174743295
# 2025-05-08 00:29:08,322  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:08,322  - Filter_2_thickness: 2.2725138664245605
# 2025-05-08 00:29:08,322  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:08,322  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:08,322  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:08,322  - Reflection_Source_takeoff_angle: 12.62820816040039
# 2025-05-08 00:29:08,322  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:08,322  - Scintillator_2_thickness: 0.4645877480506897
# 2025-05-08 00:29:08,322  -
# 2025-05-08 00:29:08,749  - Iteration: 45
# 2025-05-08 00:29:08,854  - Cost: 0.00048711226554587483
# 2025-05-08 00:29:08,854  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:08,854  - Filter_2_thickness: 2.3075947761535645
# 2025-05-08 00:29:08,854  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:08,854  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:08,854  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:08,854  - Reflection_Source_takeoff_angle: 14.49166202545166
# 2025-05-08 00:29:08,854  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:08,854  - Scintillator_2_thickness: 0.5
# 2025-05-08 00:29:08,854  -
# 2025-05-08 00:29:10,570  - Stopping at epoch 46 because updates are too small.
# 2025-05-08 00:29:10,570  - Cost: 0.0004871122946497053
# 2025-05-08 00:29:10,570  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:10,570  - Filter_2_thickness: 2.3075942993164062
# 2025-05-08 00:29:10,571  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:10,571  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:10,571  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:10,571  - Reflection_Source_takeoff_angle: 14.49166202545166
# 2025-05-08 00:29:10,571  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:10,571  - Scintillator_2_thickness: 0.5
# 2025-05-08 00:29:10,571  -
# 2025-05-08 00:29:10,574  - Start Estimation.
# 2025-05-08 00:29:10,602  - Initial cost: 6.034612e-03
# 2025-05-08 00:29:11,062  - Iteration: 5
# 2025-05-08 00:29:11,168  - Cost: 0.005623242352157831
# 2025-05-08 00:29:11,168  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:11,168  - Filter_2_thickness: 5.184859275817871
# 2025-05-08 00:29:11,168  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:11,168  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:11,168  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:11,168  - Reflection_Source_takeoff_angle: 22.09897804260254
# 2025-05-08 00:29:11,168  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-08 00:29:11,169  - Scintillator_2_thickness: 0.27705147862434387
# 2025-05-08 00:29:11,169  -
# 2025-05-08 00:29:11,610  - Iteration: 10
# 2025-05-08 00:29:11,777  - Cost: 0.004278995096683502
# 2025-05-08 00:29:11,777  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:11,777  - Filter_2_thickness: 4.364658355712891
# 2025-05-08 00:29:11,778  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:11,778  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:11,778  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:11,778  - Reflection_Source_takeoff_angle: 5.163866996765137
# 2025-05-08 00:29:11,778  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-08 00:29:11,778  - Scintillator_2_thickness: 0.43004530668258667
# 2025-05-08 00:29:11,778  -
# 2025-05-08 00:29:13,565  - Stopping at epoch 11 because updates are too small.
# 2025-05-08 00:29:13,565  - Cost: 0.004278994165360928
# 2025-05-08 00:29:13,565  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:13,565  - Filter_2_thickness: 4.364658355712891
# 2025-05-08 00:29:13,565  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:13,565  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:13,565  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:13,565  - Reflection_Source_takeoff_angle: 5.1638689041137695
# 2025-05-08 00:29:13,565  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-08 00:29:13,565  - Scintillator_2_thickness: 0.4300452768802643
# 2025-05-08 00:29:13,565  -
# 2025-05-08 00:29:13,568  - Start Estimation.
# 2025-05-08 00:29:13,598  - Initial cost: 4.208310e-03
# 2025-05-08 00:29:14,067  - Iteration: 5
# 2025-05-08 00:29:14,174  - Cost: 0.002403784543275833
# 2025-05-08 00:29:14,174  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:14,174  - Filter_2_thickness: 3.5510752201080322
# 2025-05-08 00:29:14,174  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:14,174  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:14,174  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:14,174  - Reflection_Source_takeoff_angle: 24.421960830688477
# 2025-05-08 00:29:14,174  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:14,174  - Scintillator_2_thickness: 0.2813224494457245
# 2025-05-08 00:29:14,174  -
# 2025-05-08 00:29:14,608  - Iteration: 10
# 2025-05-08 00:29:14,715  - Cost: 0.0017618346028029919
# 2025-05-08 00:29:14,715  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:14,715  - Filter_2_thickness: 2.7192041873931885
# 2025-05-08 00:29:14,715  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:14,715  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:14,715  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:14,715  - Reflection_Source_takeoff_angle: 22.131349563598633
# 2025-05-08 00:29:14,715  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:14,715  - Scintillator_2_thickness: 0.3431830406188965
# 2025-05-08 00:29:14,715  -
# 2025-05-08 00:29:15,149  - Iteration: 15
# 2025-05-08 00:29:15,253  - Cost: 0.0009564805659465492
# 2025-05-08 00:29:15,253  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:15,254  - Filter_2_thickness: 2.0062813758850098
# 2025-05-08 00:29:15,254  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:15,254  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:15,254  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:15,254  - Reflection_Source_takeoff_angle: 14.599942207336426
# 2025-05-08 00:29:15,254  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:15,254  - Scintillator_2_thickness: 0.4475502073764801
# 2025-05-08 00:29:15,254  -
# 2025-05-08 00:29:15,649  - Iteration: 20
# 2025-05-08 00:29:15,755  - Cost: 0.0005283767241053283
# 2025-05-08 00:29:15,755  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:15,755  - Filter_2_thickness: 1.5841127634048462
# 2025-05-08 00:29:15,755  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:15,755  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:15,755  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:15,755  - Reflection_Source_takeoff_angle: 6.896737098693848
# 2025-05-08 00:29:15,755  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:15,755  - Scintillator_2_thickness: 0.5
# 2025-05-08 00:29:15,755  -
# 2025-05-08 00:29:16,213  - Iteration: 25
# 2025-05-08 00:29:16,321  - Cost: 0.0005217918660491705
# 2025-05-08 00:29:16,321  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:16,321  - Filter_2_thickness: 1.5149558782577515
# 2025-05-08 00:29:16,321  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:16,321  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:16,321  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:16,321  - Reflection_Source_takeoff_angle: 6.329717636108398
# 2025-05-08 00:29:16,321  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:16,321  - Scintillator_2_thickness: 0.5
# 2025-05-08 00:29:16,321  -
# 2025-05-08 00:29:16,750  - Iteration: 30
# 2025-05-08 00:29:16,838  - Cost: 0.0005208535003475845
# 2025-05-08 00:29:16,838  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:16,838  - Filter_2_thickness: 1.485921025276184
# 2025-05-08 00:29:16,838  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:16,838  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:16,838  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:16,838  - Reflection_Source_takeoff_angle: 6.080395221710205
# 2025-05-08 00:29:16,838  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:16,838  - Scintillator_2_thickness: 0.5
# 2025-05-08 00:29:16,838  -
# 2025-05-08 00:29:17,899  - Stopping at epoch 32 because updates are too small.
# 2025-05-08 00:29:17,899  - Cost: 0.0005208426155149937
# 2025-05-08 00:29:17,899  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:17,899  - Filter_2_thickness: 1.4746506214141846
# 2025-05-08 00:29:17,899  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:17,899  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:17,899  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:17,899  - Reflection_Source_takeoff_angle: 6.013920783996582
# 2025-05-08 00:29:17,899  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:17,899  - Scintillator_2_thickness: 0.5
# 2025-05-08 00:29:17,899  -
# 2025-05-08 00:29:17,903  - Start Estimation.
# 2025-05-08 00:29:17,931  - Initial cost: 2.829367e-03
# 2025-05-08 00:29:18,390  - Iteration: 5
# 2025-05-08 00:29:18,498  - Cost: 0.002106552245095372
# 2025-05-08 00:29:18,498  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:18,498  - Filter_2_thickness: 4.3080596923828125
# 2025-05-08 00:29:18,498  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:18,498  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:18,498  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:18,498  - Reflection_Source_takeoff_angle: 24.61682891845703
# 2025-05-08 00:29:18,498  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-08 00:29:18,498  - Scintillator_2_thickness: 0.2408124804496765
# 2025-05-08 00:29:18,498  -
# 2025-05-08 00:29:18,923  - Iteration: 10
# 2025-05-08 00:29:19,027  - Cost: 0.001935866428539157
# 2025-05-08 00:29:19,027  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:19,027  - Filter_2_thickness: 3.948458194732666
# 2025-05-08 00:29:19,027  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:19,027  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:19,027  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:19,027  - Reflection_Source_takeoff_angle: 22.86834716796875
# 2025-05-08 00:29:19,027  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-08 00:29:19,027  - Scintillator_2_thickness: 0.2316901683807373
# 2025-05-08 00:29:19,027  -
# 2025-05-08 00:29:19,450  - Iteration: 15
# 2025-05-08 00:29:19,573  - Cost: 0.001631045015528798
# 2025-05-08 00:29:19,573  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:19,573  - Filter_2_thickness: 3.1438615322113037
# 2025-05-08 00:29:19,573  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:19,573  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:19,573  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:19,573  - Reflection_Source_takeoff_angle: 14.006842613220215
# 2025-05-08 00:29:19,573  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-08 00:29:19,573  - Scintillator_2_thickness: 0.1978054642677307
# 2025-05-08 00:29:19,573  -
# 2025-05-08 00:29:21,358  - Stopping at epoch 16 because updates are too small.
# 2025-05-08 00:29:21,358  - Cost: 0.0016310440842062235
# 2025-05-08 00:29:21,358  - Filter_2_material: Material(formula='Al', density=2.702)
# 2025-05-08 00:29:21,358  - Filter_2_thickness: 3.1438612937927246
# 2025-05-08 00:29:21,358  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:21,358  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:21,358  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:21,358  - Reflection_Source_takeoff_angle: 14.006843566894531
# 2025-05-08 00:29:21,358  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-08 00:29:21,358  - Scintillator_2_thickness: 0.1978054940700531
# 2025-05-08 00:29:21,358  -
# 2025-05-08 00:29:21,361  - Start Estimation.
# 2025-05-08 00:29:21,387  - Initial cost: 1.623197e-01
# 2025-05-08 00:29:23,238  - Stopping at epoch 2 because updates are too small.
# 2025-05-08 00:29:23,239  - Cost: 0.15901027619838715
# 2025-05-08 00:29:23,239  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-08 00:29:23,239  - Filter_2_thickness: 0.0
# 2025-05-08 00:29:23,239  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:23,239  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:23,239  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:23,239  - Reflection_Source_takeoff_angle: 26.242597579956055
# 2025-05-08 00:29:23,239  - Scintillator_2_material: Material(formula='CsI', density=4.51)
# 2025-05-08 00:29:23,239  - Scintillator_2_thickness: 0.23870021104812622
# 2025-05-08 00:29:23,239  -
# 2025-05-08 00:29:23,242  - Start Estimation.
# 2025-05-08 00:29:23,270  - Initial cost: 1.628759e-01
# 2025-05-08 00:29:25,196  - Stopping at epoch 2 because updates are too small.
# 2025-05-08 00:29:25,196  - Cost: 0.1545529067516327
# 2025-05-08 00:29:25,196  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-08 00:29:25,196  - Filter_2_thickness: 0.0
# 2025-05-08 00:29:25,196  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:25,196  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:25,196  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:25,196  - Reflection_Source_takeoff_angle: 26.23041343688965
# 2025-05-08 00:29:25,196  - Scintillator_2_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-08 00:29:25,196  - Scintillator_2_thickness: 0.23743784427642822
# 2025-05-08 00:29:25,196  -
# 2025-05-08 00:29:25,200  - Start Estimation.
# 2025-05-08 00:29:25,226  - Initial cost: 1.639951e-01
# 2025-05-08 00:29:27,045  - Stopping at epoch 2 because updates are too small.
# 2025-05-08 00:29:27,045  - Cost: 0.15015245974063873
# 2025-05-08 00:29:27,045  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-08 00:29:27,045  - Filter_2_thickness: 0.0
# 2025-05-08 00:29:27,045  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:27,045  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:27,045  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:27,045  - Reflection_Source_takeoff_angle: 26.21799087524414
# 2025-05-08 00:29:27,045  - Scintillator_2_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-08 00:29:27,045  - Scintillator_2_thickness: 0.24686181545257568
# 2025-05-08 00:29:27,045  -
# 2025-05-08 00:29:27,048  - Start Estimation.
# 2025-05-08 00:29:27,074  - Initial cost: 1.628911e-01
# 2025-05-08 00:29:28,963  - Stopping at epoch 2 because updates are too small.
# 2025-05-08 00:29:28,964  - Cost: 0.1365768015384674
# 2025-05-08 00:29:28,964  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-08 00:29:28,964  - Filter_2_thickness: 0.0
# 2025-05-08 00:29:28,964  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:28,964  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:28,964  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:28,964  - Reflection_Source_takeoff_angle: 26.224502563476562
# 2025-05-08 00:29:28,964  - Scintillator_2_material: Material(formula='CdWO4', density=7.9)
# 2025-05-08 00:29:28,964  - Scintillator_2_thickness: 0.25040003657341003
# 2025-05-08 00:29:28,964  -
# 2025-05-08 00:29:28,967  - Start Estimation.
# 2025-05-08 00:29:28,993  - Initial cost: 1.602464e-01
# 2025-05-08 00:29:30,774  - Stopping at epoch 1 because updates are too small.
# 2025-05-08 00:29:30,774  - Cost: 0.1602463573217392
# 2025-05-08 00:29:30,774  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-08 00:29:30,774  - Filter_2_thickness: 5.000000476837158
# 2025-05-08 00:29:30,774  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:30,774  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:30,774  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:30,774  - Reflection_Source_takeoff_angle: 24.999998092651367
# 2025-05-08 00:29:30,774  - Scintillator_2_material: Material(formula='Y3Al5O12', density=4.56)
# 2025-05-08 00:29:30,774  - Scintillator_2_thickness: 0.2499999850988388
# 2025-05-08 00:29:30,774  -
# 2025-05-08 00:29:30,777  - Start Estimation.
# 2025-05-08 00:29:30,803  - Initial cost: 1.628165e-01
# 2025-05-08 00:29:32,707  - Stopping at epoch 2 because updates are too small.
# 2025-05-08 00:29:32,707  - Cost: 0.13239194452762604
# 2025-05-08 00:29:32,707  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-08 00:29:32,707  - Filter_2_thickness: 0.0
# 2025-05-08 00:29:32,708  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:32,708  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:32,708  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:32,708  - Reflection_Source_takeoff_angle: 26.231678009033203
# 2025-05-08 00:29:32,708  - Scintillator_2_material: Material(formula='Bi4Ge3O12', density=7.13)
# 2025-05-08 00:29:32,708  - Scintillator_2_thickness: 0.24081052839756012
# 2025-05-08 00:29:32,708  -
# 2025-05-08 00:29:32,711  - Start Estimation.
# 2025-05-08 00:29:32,737  - Initial cost: 1.637673e-01
# 2025-05-08 00:29:34,601  - Stopping at epoch 2 because updates are too small.
# 2025-05-08 00:29:34,601  - Cost: 0.14017102122306824
# 2025-05-08 00:29:34,601  - Filter_2_material: Material(formula='Cu', density=8.92)
# 2025-05-08 00:29:34,601  - Filter_2_thickness: 0.0
# 2025-05-08 00:29:34,601  - Reflection_Source_1_voltage: 40.0
# 2025-05-08 00:29:34,601  - Reflection_Source_2_voltage: 80.0
# 2025-05-08 00:29:34,601  - Reflection_Source_3_voltage: 180.0
# 2025-05-08 00:29:34,601  - Reflection_Source_takeoff_angle: 26.203083038330078
# 2025-05-08 00:29:34,601  - Scintillator_2_material: Material(formula='Gd2O2S', density=7.32)
# 2025-05-08 00:29:34,601  - Scintillator_2_thickness: 0.2338305115699768
# 2025-05-08 00:29:34,601  -

# %% [markdown]
# ### B07. Result Analysis

# %%
import torch

# Get the estimated effective response for each source voltage.
# Make sure to convert to numpy array from tensor before plotting.
est_sp = Estimator.get_spectra()

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i in range(3):
    ax = axs[i]
    with torch.no_grad():
        ax.plot(energies[:voltage_list[i]-1], (gt_spec_list[i]/np.trapezoid(gt_spec_list[i],energies))[:voltage_list[i]-1],
                label='Ground Truth')
        es = est_sp[i].numpy()
        es /= np.trapezoid(es,energies)
        ax.plot(energies[:voltage_list[i]-1], es[:voltage_list[i]-1], '--', label='Estimate')

    ax.legend()
    ax.set_title(f'{voltage_list[i]} kV Spectral Response')

fig.suptitle('Comparison of Ground Truth and Estimate')
plt.show()

# %%
import pandas as pd

# Return a dictionary containing the estimated parameters.
res_params = Estimator.get_params()

# Ground Truth values
ground_truth = {
    "takeoff_angle (degree)": takeoff_angle,
    "fltr_mat": fltr_mat,
    "fltr_th (mm)": fltr_th,
    "det_mat": det_mat,
    "det_th (mm)": det_th,
}

# Estimated values from res_params
# .item() to return value for an estiamted continous parameter.
# material with .formula is because the class Material contains both formula and density.
estimated = {
    "takeoff_angle (degree)": res_params['Reflection_Source_takeoff_angle'].item(),
    "fltr_mat": res_params['Filter_2_material'].formula,
    "fltr_th (mm)": res_params['Filter_2_thickness'].item(),
    "det_mat": res_params['Scintillator_2_material'].formula,
    "det_th (mm)": res_params['Scintillator_2_thickness'].item(),
}

# Combine into a DataFrame for comparison
df = pd.DataFrame({'Ground Truth': ground_truth, 'Estimated': estimated})

# Display the DataFrame
df
# Out:
#                        Ground Truth  Estimated
# takeoff_angle (degree)           13  14.344031
# fltr_mat                         Al         Al
# fltr_th (mm)                      3   3.096184
# det_mat                         CsI        CsI
# det_th (mm)                    0.33   0.343391
