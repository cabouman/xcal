# %% [markdown]
# # Tutorial 02: Model-Based Spectral Calibration using MBIRJAX
# This tutorial introduces a **model-based spectral calibration** approach using the [MBIRJAX](https://github.com/cabouman/mbirjax)
#  projector.
#
# In this tutorial, we will
# - simulate multi-energy dataset using MBIRJAX projector
#   - simulate CT scans with specific source, filter, and detector configurations.
#   - scan multiple materials at different source voltages to generate multi-energy dataset.
# - model-based spectral calibration
#   - Step 0: Obtain sample masks and calculate forward matrix.
#   - Step 1: Configure Spectral Models including source, filters, and detector(scintillator).
#   - Step 2: Spectral Calibration.

# %% [markdown]
# ## X-ray System Setup
#
# ### Source
# - **Type**: Reflection
# - **Take-off Angle**: 13°
# - **Voltages Used for Scanning**:
#   - 50 kV
#   - 100 kV
#   - 150 kV
#
# ### Filter
# - **Material**: Aluminum (Al)
# - **Thickness**: 3 mm
#
# ### Detector
# - **Material**: Cesium Iodide (CsI)
# - **Thickness**: 0.33 mm
#
# ### Samples
# - **Shapes**: Rods with 0.5 mm radius
# - **Materials**:
#   - Vanadium (V)
#   - Aluminum (Al)
#   - Titanium (Ti)
#   - Magnesium (Mg)
# - **Height**: 0.2 mm
#
# ### CT Geometry
# - **Beam Type**: Parallel Beam
# - **Detector Specifications**:
#   - **Pixel Size**: 0.01 mm × 0.01 mm
#   - **Scan Shape**: 50 × 512 pixels
# - **Number of Views**: 64

# %%
import numpy as np
import matplotlib.pyplot as plt

max_simkV = 180 # keV
takeoff_angle = 13 # degree
voltage_list = [40, 80, 180] # keV
mas_list = [0.01,0.01,0.01] # Milliampere-seconds

fltr_mat = 'Al' # filter material
fltr_th = 3 # filter thickness in mm

det_mat = 'CsI' # scintillator material
det_density = 4.51 # scintillator density g/cm^3
det_th = 0.33 # scintillator thickness in mm

sample_mats = ['V', 'Al', 'Ti', 'Mg']
sample_radius = 0.5 # sample diameter in mm


ct_info = {
    "Geometry": "Parallel",
    "psize": [0.01, 0.01],  # Width and height in mm
    "rsize": [0.01, 0.01],
    "shape": [50, 512],     # Rows and columns
    "NViews": 64
}

# %% [markdown]
# ## A. Simulate multi-energy dataset using MBIRJAX projector

# %% [markdown]
# ### A01. Ground Truth Source Spectra
# In this tutorial,
# - use spekpy to generate X-ray source spectum.
# - the description of 2 used functions from spekpy is shown below by the help function.

# %%
import spekpy as sp
help(sp.Spek.__init__)
# Out:
# Help on function __init__ in module spekpy.SpekPy:
#
# __init__(self, kvp=None, th=None, dk=None, mu_data_source=None, physics=None, x=None, y=None, z=None, mas=None, brem=None, char=None, obli=None, comment=None, targ=None, shift=None, init_default=True)
#     Constructor method for the Spek class
#
#     SEE THE WIKI PAGES FOR MORE INFO:
#     https://bitbucket.org/spekpy/spekpy_release/wiki/Further_information
#
#     :param float kvp: tube potential [kV] (default: depends on target)
#     :param float th: anode angle [degrees] (default: 12 degrees)
#     :param float dk: energy bin width [keV] (default: 0.5 keV)
#     :param string: mu_data_source (default: depends on physics model)
#         options: ('pene' or 'nist')
#     :param float physics: physics model (default: 'casim')
#         options: ('casim', 'kqp', 'spekpy-v1', 'spekcalc',
#                   'diff', 'uni', 'sim', 'classical')
#     :param float x: displacement from central axis in anode-cathode
#         direction [cm] (default: 0 cm)
#     :param float y: displacement from central axis in orthogonal
#         direction [cm] (default: 0 cm)
#     :param float z: focus-to-detector distance [cm] (default: 100 cm)
#     :param float mas: the tube current-time product [mAs] (default: 1 mAs)
#     :param logical brem: whether bremsstrahlung x rays requested
#         (default: true)
#     :param logical char: whether characteristic x rays requested
#         (default: true)
#     :param logical obli: whether increased oblique paths through filtration
#         are assumed for off axis positions (default: true)
#     :param string comment: any text annotation the user wishes to add
#     :param string targ: the anode target material (default: 'W')
#         options: ('W', 'Mo', or 'Rh')
#     :param float shift: optional fraction of an energy bin to shift the
#         energy bins (useful when matching to measurements) (default: 0.0)

# %%
help(sp.Spek.get_spectrum)
# Out:
# Help on function get_spectrum in module spekpy.SpekPy:
#
# get_spectrum(self, edges=False, flu=True, diff=True, sig=None, addend=False, **kwargs)
#     A method to get the energy and spectrum for the parameters in the
#     current spekpy state
#
#     :param bool edges: Keyword argument to determine whether midbin or edge
#         of bins data are returned
#     :param bool addend: Keyword argument to determine whether a zero
#         end point is added to the spectrum
#     :param bool flu: Whether to return fluence or energy-fluence
#     :param bool diff: Whether to return spectrum differential in energy
#     :param kwargs: Keyword arguments to change parameters that are used for
#         the calculation
#     :return array k: Array with photon energies (mid-bin or edge values)
#         [keV]
#     :return array spk: Array with corresponding photon fluences
#         [Photons cm^-2 keV^-1], [Photons cm^-2] or [Photons cm^-2 keV^1]
#         depending of values of flu and diff inputs

# %%
max_simkV = max(voltage_list)
takeoff_angle = 13

# Define energy bins from 1.5 keV up to (max_simkV - 0.5) keV.
energies = np.linspace(1.5, max_simkV - 0.5, max_simkV-1)

# Initialize an empty list to store the generated source spectra.
gt_src_spec_list = []

for case_i, simkV in enumerate(voltage_list):
    # Generate the X-ray spectrum model with Spekpy for each voltage.
    # kvp is source voltage
    # th is anode angle
    # dk is energy bin size
    # z is focus-to-detector distance [cm], use source-detector distance instead and convert mm to cm.
    # mas is current-time product mA*s
    # char=True requests characteristic x rays.
    s = sp.Spek(kvp=simkV, th=takeoff_angle, dk=1,z=1, mas=mas_list[case_i], char=True)
    
    # Return data at the mid of a bin or the edges of a bin.
    k, phi_k = s.get_spectrum(edges=False)  # Retrieve energy bins and fluence spectrum [Photons cm^-2 keV^-1]
    
    # Adjust the fluence for the detector pixel area.
    phi_k = phi_k * ((ct_info['psize'][0] / 10) * (ct_info['psize'][1] / 10))  # Convert pixel size from cm² to mm²

    # Initialize a zero-filled spectrum array with length max_simkV.
    src_spec = np.zeros(max_simkV-1)
    src_spec[:simkV-1] = phi_k  # Assign spectrum values starting from 1.5 keV

    # Add the processed spectrum for this voltage to the list.
    gt_src_spec_list.append(src_spec)

# Convert the list of source spectra to a numpy array for easy handling.
gt_src_spec_list = np.array(gt_src_spec_list)

# Plot each generated source spectrum.
for src_i, gt_src_spec in enumerate(gt_src_spec_list):
    plt.plot(energies, gt_src_spec, label='%d kV' % voltage_list[src_i])

plt.title('Ground Truth Source Spectra')
plt.xlabel('Energy (keV)')
plt.ylabel('Photons per pixel [$mm^{-2}$ $keV^{-1}$]')
plt.grid()
plt.legend()

# %% [markdown]
# #### A02. Ground Truth Filter Response
# Filter response is defined as
# $$
# f(E) = e^{-\mu(m, E)\cdot t}
# $$
# where $t$ is thickness; $\mu$ is linear attenuation coefficient(LAC), which depends on photon energy and material $m$ formula and density.

# %%
from xcal import get_filter_response
from xcal.chem_consts._periodictabledata import density

# get_filter_response returns a ratio of passing through photons.
# F(E) = e^(-\mu_{mat}(E)*thickness) 
# \mu_{mat}(E) = mac{mat}(E) * density
# where \mu denotes linear attenuation coefficient; mac means mass attenuation coefficient.
gt_fltr = get_filter_response(energies, fltr_mat, density[fltr_mat], fltr_th)

plt.plot(energies, gt_fltr, label='3mm Al')
plt.title('Ground Truth Filter Response')
plt.legend()
plt.xlabel('Energy (keV)')
plt.grid()

# %% [markdown]
# ### A03. Ground Truth Detector Response
#
# Converted energy from a X-ray photon with energy from 1 to 180 keV.
#
# Detector response is defined as
# $$
# D(E) =\frac{\mu_{en}(m, E)}{\mu(m, E)} (1 - e^{-\mu(m, E)\cdot t} )
# $$
# where $t$ is scintillator thickness; $\mu$ is linear attenuation coefficient(LAC), which depends on photon energy $E$ and material $m$ formula and density; $\mu_en$ is linear energy-absorption coefficient(LAC).

# %%
from xcal import get_scintillator_response
from xcal.chem_consts._periodictabledata import density

# get_scintillator_response returns converted energy per photon at energy E.
# D(E) = -\mu_en/\mu * (1-e^(-\mu(E)*thickness))
# \mu(E) = mac(E) * density
# \mu_en(E) = mac_en(E) * density
# where \mu denotes linear attenuation coefficient; mac means mass attenuation coefficient.
# where \mu_en denotes linear energy-absorption coefficient; mac_en means mass energy-absorption coefficient.
gt_det = get_scintillator_response(energies, det_mat, det_density, det_th)

plt.plot(energies, gt_det, label='%.2fmm %s'%(det_th, det_mat))
plt.title('Ground Truth Scintillator Response')
plt.legend()
plt.xlabel('Energy (keV)')
plt.grid()

# %% [markdown]
# ### A04. Linear Attenuation Coefficients of homogenous samples

# %%
from xcal.chem_consts import get_lin_att_c_vs_E
help(get_lin_att_c_vs_E)
# Out:
# Help on function get_lin_att_c_vs_E in module xcal.chem_consts._consts_from_table:
#
# get_lin_att_c_vs_E(density, formula, energy_vector)
#     Calculate the linear attenuation coefficient (mu) as a function of energy,
#     using mass attenuation coefficients from the NIST website:
#     https://physics.nist.gov/PhysRefData/XrayMassCoef/tab3.html.
#
#     Author: Wenrui Li, Purdue University
#     Date: 04/12/2022
#
#     Parameters
#     ----------
#     density : float
#         Density of the material in g/cm^3.
#     formula : str/dict
#         Chemical formula of the compound, either as a string or a dict.
#         For example, "H2O" and {"H": 2, "O": 1} are both acceptable.
#     energy_vector : list/numpy.ndarray
#         Energy (units: keV) list or 1D array for which beta values are calculated.
#
#     Returns
#     -------
#     numpy.ndarray
#         Linear attenuation coefficient values in mm^-1, with the same size as energy_vector.

# %%
# Scanned Homogeneous Rods
# Density for homogenous material is stored in the imported density dictionary
mat_density = [density[formula] for formula in sample_mats]
lac_vs_E_list = [get_lin_att_c_vs_E(den, formula, energies) for den, formula in zip(mat_density, sample_mats)]

# Plot LAC
for lac_vs_E,mat in zip(lac_vs_E_list, sample_mats):
    plt.plot(energies, lac_vs_E, label=mat)
plt.yscale('log')
plt.title(r'Linear Attenuation Coefficient $\mu$ ($mm^{-1}$)')
plt.xlabel('Energy (keV)')
plt.grid()
plt.legend()

# %% [markdown]
# ### A05. GT X-ray System Spectral Responses

# %%
gt_spec_list = [gt_source * gt_fltr  * gt_det for gt_source in gt_src_spec_list]
for spec_i, gt_spec in enumerate(gt_spec_list):
    plt.plot(energies, gt_spec/np.trapezoid(gt_spec,energies), label='%d kV'%voltage_list[spec_i])
plt.legend()
plt.title('Ground Truth: X-ray System Spectral Response')
plt.xlabel('Energy (keV)')
plt.grid()
plt.legend()

# %% [markdown]
# ### A06. Masks for 4 homogenous samples
#
# Obtain a list of mask for each corresponding homogenous sample rod.
# These masks is then used to calculate the forward matrix for the transmission function.

# %%
from xcal._utils import Gen_Circle
help(Gen_Circle.__init__)
# Out:
# Help on function __init__ in module xcal._utils:
#
# __init__(self, canvas_shape, pixel_size)
#     Initialize the Circle class.
#
#     Parameters:
#     canvas_shape (tuple): The shape of the canvas, in pixels.
#     pixel_size (tuple): The size of a pixel, in the same units as the canvas.

# %%
help(Gen_Circle.generate_mask)
# Out:
# Help on function generate_mask in module xcal._utils:
#
# generate_mask(self, radius, center=None)
#     Generate a binary mask for the circle.
#
#     Parameters:
#     radius (int): The radius of the circle, in pixels.
#     center (tuple): The center of the circle.
#
#     Returns:
#     ndarray: A 2D numpy array where points inside the circle are marked as True and points outside are marked as False.

# %%
# Define parameters for 4 cylinders with 0.5mm radius, evenly distributed on a circle with a radius of 1.5mm.
Radius = [sample_radius for _ in range(len(sample_mats))]  # Radius of each cylindrical cross-section in mm
arrange_with_radius = 1.5  # Radius of the circle on which cylinder centers are distributed (in mm)

# Calculate center positions for each cylinder, evenly spaced around the circular arrangement
centers = [[np.sin(rad_angle) * arrange_with_radius, np.cos(rad_angle) * arrange_with_radius]
           for rad_angle in np.linspace(-np.pi / 2, -np.pi / 2 + np.pi * 2, len(sample_mats), endpoint=False)]

# Generate 3D masks for each cylinder
# Obtain a list of mask for each corresponding homogenous sample rod. 
# These masks is then used to calculate the forward matrix for the transmission function.
mask_list = []
for mat_id, mat in enumerate(sample_mats):
    # Initialize a circular mask generator for 2D slices
    # Use the number of column pixels to define a canvas
    circle = Gen_Circle((ct_info["shape"][1], ct_info["shape"][1]), 
                        (ct_info["rsize"][0], ct_info["rsize"][1])) # Image volume size
    # Create a 3D mask array for the current cylinder by repeating the circular 2D mask across slices
    mask_3d = np.array([circle.generate_mask(Radius[mat_id], centers[mat_id]) 
                        for i in range(ct_info["shape"][0])]).transpose((1,2,0))
    mask_list.append(mask_3d)

# Below just for display    
# Initialize the phantom array to hold combined cylinder masks
phantom = np.zeros(mask_list[0].shape)    

# Combine all masks into the phantom, weighted by the linear attenuation coefficients for each material
for mat_id, mat in enumerate(sample_mats):
    phantom += mask_list[mat_id] * np.mean(lac_vs_E_list[mat_id])

# Display a slice of the phantom (e.g., 26th slice) to show cross-sectional circles of cylinders
plt.imshow(phantom[:,:,25], extent=[-2.56, 2.56, -2.56, 2.56], origin='lower')

# Annotate each circle with its corresponding material name
for mat_id, mat in enumerate(sample_mats):
    plt.text(centers[mat_id][1], centers[mat_id][0], mat, fontsize=15, ha='right', color='red')
plt.title('Phantom: 4 homogenous samples')
# Out:
# Text(0.5, 1.0, 'Phantom: 4 homogenous samples')

# %% [markdown]
# ### A07. Setup forward projector with MBIRJAX

# %%
import time
import mbirjax

class fw_projector:
    def __init__(self, angles, num_rows, num_channels, delta_pixel=1):
        """

        Parameters
        ----------
        energies
        N_views
        psize
        xcenter
        arange
        """
        self.angles = angles
        self.num_rows = num_rows
        self.num_channels = num_channels
        self.delta_pixel = delta_pixel
        self.sinogram_shape = (len(angles), self.num_rows, self.num_channels)

    def forward(self, mask):
        """

        Parameters
        ----------
        mask : numpy.ndarray
            3D mask for pure solid object.

        Returns
        -------
        lai : numpy.ndarray
            Linear attenuation integral, of size M measurement * N energy bins.

        """

        ct_model_for_generation = mbirjax.ParallelBeamModel(self.sinogram_shape, self.angles)
        # Print out model parameters
        ct_model_for_generation.print_params()
        projections = ct_model_for_generation.forward_project(mask) * self.delta_pixel

        return projections
    
angles = np.linspace(-np.pi/2, np.pi, ct_info['NViews'], endpoint=False)
projector = fw_projector(angles, num_rows=ct_info["shape"][0], num_channels=ct_info["shape"][1], delta_pixel=ct_info["psize"][0])

# %% [markdown]
# ### A08. Calculate Attenuation Matrix
# We let $ \mu_k(E) $ denote the LAC of the $k^\text{th}$ homogeneous sample at energy $E$, and let $L_{k, i}$ denote the path length through the $k^{th}$ material at projection $i$ for samples $k=0, \ldots, K-1$.
# The attenuation matrix is calculated as below,
# $$
# A(E) = \exp \left\{-\sum_{k=0}^{K-1} \mu_k(E) L_{k, i}\right\}
# $$
#
# Notice that $L_{k, i}$ is calcuated by projecting $k^\text{th}$ mask in mask_list with a projector defined in A07.
# One should create the “projector” object in a similar way defined in A07 if use CT projector other than MBIRJAX.

# %%
from xcal import calc_forward_matrix
spec_F = calc_forward_matrix(mask_list, lac_vs_E_list, projector)
# Out:
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (64, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----

# %% [markdown]
# ### A09. Simulate Transmission Data

# %%
trans_list = []
for case_i, gt_spec in zip(np.arange(len(gt_spec_list)), gt_spec_list):
    # Obtain the converted energy, which is proportional to the detected visible light photons by the camera.
    # gt_spec is the converted energy without an object.
    # Notice that, trapezoid does the energy integration.
    trans = np.trapezoid(spec_F * gt_spec, energies, axis=-1) # Object scan
    trans_0 = np.trapezoid(gt_spec, energies, axis=-1) # Air scan value
    # Add poisson noise.
    # The noise level can be adjusted by changing the mas, the current-time product in the beginning of this tutorial.
    trans_noise = np.random.poisson(trans).astype(np.float32)
    trans_noise /= trans_0

    # Store noisy transmission data.
    trans_list.append(trans_noise)

# %%
for case_i, gt_spec in enumerate(gt_spec_list):
    plt.plot(trans_list[case_i][3, 25], label=f'{voltage_list[case_i]} keV')
plt.legend()
plt.grid()
plt.title('Simulated Transmission Data')
# Out:
# Text(0.5, 1.0, 'Simulated Transmission Data')

# %% [markdown]
# ## B. Spectral Calibration

# %% [markdown]
# ### B01. FBP Reconstruction using MBIRJAX
# Reconstructing one CT scan using MBIR.

# %%
# Reconstructing one CT scan using MBIR.
sino = -np.log(trans_list[-1]).astype(np.float32)
sino = np.ascontiguousarray(sino, dtype=np.float32) # shape is numAngles, numRows, numCols


startTime = time.time()
sinogram_shape = (len(angles), ct_info["shape"][0], ct_info["shape"][1])
ct_model_for_recon = mbirjax.ParallelBeamModel(sinogram_shape, angles)
sharpness = 1.0
ct_model_for_recon.set_params(sharpness=sharpness)
recon, recon_params = ct_model_for_recon.recon(sino, weights=None, max_iterations=100) # shape is numZ, numY, numX
recon = recon/ct_info["psize"][0] # convert ALU^-1 to mm^-1
recon = recon.transpose((2,0,1))
print('Reconstruction Elapsed Time: ' + str(time.time()-startTime))
# Out:
# GPU used for: none
# Estimated GPU memory required = 0.000 GB, available = 0.000 GB
# Estimated CPU memory required = 1.111 GB, available = 5.326 GB
# Starting direct recon for initial reconstruction
# Initializing error sinogram
# Computing Hessian diagonal
# Starting VCD iterations
#
# After iteration 0 of a max of 100: Pct change=28.4700, Forward loss=2.4480
# Relative step size (alpha)=0.23, Error sino RMSE=0.0284
# Number subsets = 1
#
# After iteration 1 of a max of 100: Pct change=36.4149, Forward loss=0.8540
# Relative step size (alpha)=1.46, Error sino RMSE=0.0099
# Number subsets = 16
#
# After iteration 2 of a max of 100: Pct change=15.9112, Forward loss=0.6960
# Relative step size (alpha)=1.50, Error sino RMSE=0.0081
# Number subsets = 64
#
# After iteration 3 of a max of 100: Pct change=8.0987, Forward loss=0.6837
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 4 of a max of 100: Pct change=4.8590, Forward loss=0.6811
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 5 of a max of 100: Pct change=3.4379, Forward loss=0.6842
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 6 of a max of 100: Pct change=2.6386, Forward loss=0.6835
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 7 of a max of 100: Pct change=2.1367, Forward loss=0.6847
# Relative step size (alpha)=1.50, Error sino RMSE=0.0080
# Number subsets = 128
#
# After iteration 8 of a max of 100: Pct change=1.7819, Forward loss=0.6839
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 9 of a max of 100: Pct change=1.5283, Forward loss=0.6842
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 10 of a max of 100: Pct change=1.3310, Forward loss=0.6835
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 11 of a max of 100: Pct change=1.1758, Forward loss=0.6835
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 12 of a max of 100: Pct change=1.0493, Forward loss=0.6830
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 13 of a max of 100: Pct change=0.9473, Forward loss=0.6829
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 14 of a max of 100: Pct change=0.8591, Forward loss=0.6825
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 15 of a max of 100: Pct change=0.7908, Forward loss=0.6824
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 16 of a max of 100: Pct change=0.7354, Forward loss=0.6821
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 17 of a max of 100: Pct change=0.6931, Forward loss=0.6820
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 18 of a max of 100: Pct change=0.6510, Forward loss=0.6817
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 19 of a max of 100: Pct change=0.6199, Forward loss=0.6816
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 20 of a max of 100: Pct change=0.5931, Forward loss=0.6814
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 21 of a max of 100: Pct change=0.5724, Forward loss=0.6813
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 22 of a max of 100: Pct change=0.5601, Forward loss=0.6811
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 23 of a max of 100: Pct change=0.5457, Forward loss=0.6811
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 24 of a max of 100: Pct change=0.5386, Forward loss=0.6809
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 25 of a max of 100: Pct change=0.5352, Forward loss=0.6809
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 26 of a max of 100: Pct change=0.5315, Forward loss=0.6807
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 27 of a max of 100: Pct change=0.5278, Forward loss=0.6807
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 28 of a max of 100: Pct change=0.5254, Forward loss=0.6805
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 29 of a max of 100: Pct change=0.5249, Forward loss=0.6805
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 30 of a max of 100: Pct change=0.5257, Forward loss=0.6804
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 31 of a max of 100: Pct change=0.5284, Forward loss=0.6804
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 32 of a max of 100: Pct change=0.5308, Forward loss=0.6803
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 33 of a max of 100: Pct change=0.5381, Forward loss=0.6803
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 34 of a max of 100: Pct change=0.5452, Forward loss=0.6802
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 35 of a max of 100: Pct change=0.5541, Forward loss=0.6802
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 36 of a max of 100: Pct change=0.5662, Forward loss=0.6801
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 37 of a max of 100: Pct change=0.5684, Forward loss=0.6801
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 38 of a max of 100: Pct change=0.5644, Forward loss=0.6800
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 39 of a max of 100: Pct change=0.5710, Forward loss=0.6800
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 40 of a max of 100: Pct change=0.5862, Forward loss=0.6799
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 41 of a max of 100: Pct change=0.5992, Forward loss=0.6800
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 42 of a max of 100: Pct change=0.6080, Forward loss=0.6799
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 43 of a max of 100: Pct change=0.6136, Forward loss=0.6799
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 44 of a max of 100: Pct change=0.6194, Forward loss=0.6798
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 45 of a max of 100: Pct change=0.6278, Forward loss=0.6799
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 46 of a max of 100: Pct change=0.6343, Forward loss=0.6798
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 47 of a max of 100: Pct change=0.6386, Forward loss=0.6798
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 48 of a max of 100: Pct change=0.6499, Forward loss=0.6797
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 49 of a max of 100: Pct change=0.6572, Forward loss=0.6798
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 50 of a max of 100: Pct change=0.6570, Forward loss=0.6797
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 51 of a max of 100: Pct change=0.6613, Forward loss=0.6797
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 52 of a max of 100: Pct change=0.6776, Forward loss=0.6797
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 53 of a max of 100: Pct change=0.6845, Forward loss=0.6797
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 54 of a max of 100: Pct change=0.6954, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 55 of a max of 100: Pct change=0.7162, Forward loss=0.6797
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 56 of a max of 100: Pct change=0.7269, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 57 of a max of 100: Pct change=0.7262, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 58 of a max of 100: Pct change=0.7265, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 59 of a max of 100: Pct change=0.7280, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 60 of a max of 100: Pct change=0.7288, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 61 of a max of 100: Pct change=0.7389, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 62 of a max of 100: Pct change=0.7480, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 63 of a max of 100: Pct change=0.7529, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 64 of a max of 100: Pct change=0.7682, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 65 of a max of 100: Pct change=0.7839, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 66 of a max of 100: Pct change=0.7796, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 67 of a max of 100: Pct change=0.7792, Forward loss=0.6796
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 68 of a max of 100: Pct change=0.7986, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 69 of a max of 100: Pct change=0.8143, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 70 of a max of 100: Pct change=0.8246, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 71 of a max of 100: Pct change=0.8357, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 72 of a max of 100: Pct change=0.8421, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 73 of a max of 100: Pct change=0.8373, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 74 of a max of 100: Pct change=0.8372, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 75 of a max of 100: Pct change=0.8433, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 76 of a max of 100: Pct change=0.8526, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 77 of a max of 100: Pct change=0.8726, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 78 of a max of 100: Pct change=0.8756, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 79 of a max of 100: Pct change=0.8736, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 80 of a max of 100: Pct change=0.8795, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 81 of a max of 100: Pct change=0.8925, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 82 of a max of 100: Pct change=0.9009, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 83 of a max of 100: Pct change=0.9128, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 84 of a max of 100: Pct change=0.9277, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 85 of a max of 100: Pct change=0.9461, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 86 of a max of 100: Pct change=0.9645, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 87 of a max of 100: Pct change=0.9872, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 88 of a max of 100: Pct change=1.0066, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 89 of a max of 100: Pct change=1.0048, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 90 of a max of 100: Pct change=0.9970, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 91 of a max of 100: Pct change=0.9924, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 92 of a max of 100: Pct change=0.9960, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 93 of a max of 100: Pct change=1.0015, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 94 of a max of 100: Pct change=1.0019, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 95 of a max of 100: Pct change=0.9996, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 96 of a max of 100: Pct change=1.0179, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 97 of a max of 100: Pct change=1.0317, Forward loss=0.6795
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 98 of a max of 100: Pct change=1.0362, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
#
# After iteration 99 of a max of 100: Pct change=1.0324, Forward loss=0.6794
# Relative step size (alpha)=1.50, Error sino RMSE=0.0079
# Number subsets = 128
# Reconstruction Elapsed Time: 215.5702610015869

# %%
plt.imshow(recon[25])
plt.colorbar()
plt.title('Reconstruction')
# Out:
# Text(0.5, 1.0, 'Reconstruction')

# %% [markdown]
# ### B02. Circle Detection (Optional)
# The circle detection provides a coarse bounding box for object segmentation.
# One can manually set the bounding box for the object segmentation, if the sample is not cylindrical.
#
# Below is an example to use detect_hough_circles to detect circles on the $25^{th}$ slice of the reconstruction.

# %%
from xcal.phantom import detect_hough_circles

# %%
help(detect_hough_circles)
# Out:
# Help on function detect_hough_circles in module xcal.phantom:
#
# detect_hough_circles(phantom, radius_range=None, vmin=0, vmax=None, min_dist=100, HoughCircles_params1=300, HoughCircles_params2=1)
#     Detects circles in an image using the Hough Circle Transform.
#
#     Args:
#         phantom (numpy.ndarray): The 2D image to detect circles in.
#         radius_range (list of int, optional): The minimum and maximum radius of
#             circles to detect. Defaults to a range based on the image size.
#         vmin (int, optional): Minimum value for clipping the image before
#             detection. Defaults to 0.
#         vmax (int, optional): Maximum value for clipping the image before
#             detection. If None, the 90th percentile of the image is used.
#             Defaults to None.
#         min_dist (int, optional): Minimum distance between the centers of the
#             detected circles. If too small, multiple neighbor circles may be
#             falsely detected in addition to a true one. If too large, some
#             circles may be missed. Defaults to 100.
#         HoughCircles_params1 (float, optional): Upper threshold for the internal edge detection.
#         HoughCircles_params2 (float, optional): Threshold for center detection, which influences the detection sensitivity. Large param2 leads to fewer detected circles.
#
#     Returns:
#         numpy.ndarray: An array of detected circles, each represented by the
#             center coordinates (x, y) and radius. Returns an empty array if no
#             circles are detected.

# %%
from matplotlib.patches import Circle
import math

plt.imshow(recon[25],origin='lower')
plt.colorbar()
# Get the current axes.
ax = plt.gca()
circles = detect_hough_circles(recon[25], 
                               radius_range=(45, 55), 
                               vmin=0.00, vmax=0.1, 
                               min_dist=200,
                               HoughCircles_params2=10)

# Below is for display and sort the detected circles.
# x is horizontal axis, y is vertical axis. 
circles_values = np.array([np.mean(recon[25][int(y-r):int(y+r),int(x-r):int(x+r)]) for x,y,r in circles])
# Sort `circles` based on the order in `circles_values`
circles = [cir for _, cir in sorted(zip(circles_values, circles))]
# Rearrange based on material ['V', 'Al', 'Ti', 'Mg'] 
circles = [circles[i] for i in [3,1,2,0]]

# Create and add circles to the plot.
for x, y, radius in circles:
    circle = Circle((x, y), radius, color='red', fill=False)
    ax.add_patch(circle)

# Optionally set the aspect of the plot to be equal.
# This makes sure that the circles are not skewed.
ax.set_aspect('equal')
plt.title('Circle Detection')
# Show the plot with the circles.
plt.show()

# %% [markdown]
# ### B03. Segment Object to get 3D Mask
#
# segment_object is a function to segment one sample from background.

# %%
from xcal.phantom import segment_object

# %%
help(segment_object)
# Out:
# Help on function segment_object in module xcal.phantom:
#
# segment_object(phantom, vmin, vmax, canny_sigma, roi_radius=None, bbox=None)
#     Segments an object within a given region of interest (ROI) or bounding box in an image.
#
#     This function creates a segmentation mask for an object in an image. The image values
#     are clipped and normalized based on provided minimum and maximum values. Canny edge
#     detection is then applied to the normalized image. The edges are filled to create a
#     binary mask that segments the object.
#
#     Args:
#         phantom (np.array): The input image to segment.
#         vmin (float): The minimum value for clipping the image.
#         vmax (float): The maximum value for clipping the image.
#         canny_sigma (float): The standard deviation for the Gaussian filter used in
#                              Canny edge detection.
#         roi_radius (int, optional): The radius of the circular region of interest. If not
#                                     provided, it defaults to half the image size.
#         bbox (tuple of int, optional): The bounding box within which to perform segmentation,
#                                        specified as (r_min, c_min, r_max, c_max). If not
#                                        provided, the entire image is used.
#
#     Returns:
#         np.array: A binary segmentation mask of the object.

# %%
est_mask_list = []
bbox_half_size = int(np.mean([cir[2] for cir in circles])*1.1)
# Manually set the threshold based on above plot.
vmin_list = [0.02,0.01,0.2,0.01]
vmax_list = [0.7,0.02,0.4,0.02]
# Loop through each slice to get 3D mask.
for vi,cir in enumerate(circles):
    xcenter, ycenter, r = cir
    # Segment object with 3D mask
    # Set different vmin and vmax for different samples.
    # Set bbox to restrict a box region for object segmentation.
    est_mask = [segment_object(
        recon[i], 
        vmin_list[vi], 
        vmax_list[vi], 
        10, # Canny sigma in canny edge detection. Larger value is more possible to connect to a line.
        roi_radius=None,
        bbox=(
            int(ycenter - bbox_half_size),
            int(xcenter - bbox_half_size),
            int(ycenter + bbox_half_size),
            int(xcenter + bbox_half_size)
        )) for i in range(len(recon))]
    est_mask_list.append(np.array(est_mask))

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 8))

for j in range(len(est_mask_list)):
    ax = axs.flat[j]
    est_mask = est_mask_list[j]
    gtmask = mask_list[j]
    # Display the image or the difference image.
#     ax.imshow(est_mask[25],origin='lower')
    ax.imshow(est_mask[25].astype('float32')-gtmask[:,:,25].astype('float32'),vmin=-1,vmax=1,origin='lower')
# Adjust the layout
plt.tight_layout()
plt.title('Difference between estimated masks and GT mask.')
plt.show()

# %%
# Define colors for each mask
colors = ['b', 'g', 'r', 'm']  # Blue, Green, Red, Magenta for each est_mask

# Plot the 3D masks using a scatter plot with different colors
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

for i, est_mask in enumerate(est_mask_list):
    # Get the coordinates of the points where the mask is 1
    z, y, x = np.where(est_mask == 1)
    ax.scatter(x, y, z, color=colors[i], marker='o', s=1, alpha=0.7, label=sample_mats[i])

# Set labels and title
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("Estimated 3D Binary Mask Visualization with Different Colors")
plt.legend()
plt.show()

# %% [markdown]
# ### B04. Calculate Forward Matrix with Estimated 3D Masks

# %%
# Only use 8 different views for spectral calibration
NViews_For_MBSC = 8
projector2 = fw_projector(angles[::ct_info["NViews"]//NViews_For_MBSC], num_rows=ct_info["shape"][0], num_channels=ct_info["shape"][1], delta_pixel=ct_info["psize"][0])

# %%
for i in range(len(est_mask_list)):
    est_mask_list[i] = est_mask_list[i].transpose((1,2,0))
est_spec_F = calc_forward_matrix(est_mask_list, lac_vs_E_list, projector2)
# Out:
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----
# ----
# geometry_type = <class 'mbirjax.parallel_beam.ParallelBeamModel'>
# file_format = 1.0
# sinogram_shape = (8, 50, 512)
# delta_det_channel = 1.0
# delta_det_row = 1.0
# det_row_offset = 0.0
# det_channel_offset = 0.0
# sigma_y = 1.0
# recon_shape = (512, 512, 50)
# delta_voxel = 1.0
# sigma_x = 1.0
# sigma_prox = 1.0
# p = 2.0
# q = 1.2
# T = 1.0
# qggmrf_nbr_wts = [1.0, 1.0, 1.0]
# auto_regularize_flag = True
# positivity_flag = False
# snr_db = 30.0
# sharpness = 1.0
# granularity = [1, 2, 4, 8, 16, 32, 64, 128, 256]
# partition_sequence = [0, 4, 6, 7]
# verbose = 1
# use_gpu = automatic
# ----

# %% [markdown]
# ### B05. X-ray System Model Configuration

# %%
from xcal.models import Reflection_Source, Filter, Scintillator
from xcal.defs import Material

# %%
# Use Spekpy to generate a source spectra dictionary.
takeoff_angles = np.linspace(5,45,11)
src_spec_list = []
for case_i,simkV in enumerate(voltage_list):
    for ta in takeoff_angles:
        # Generate the X-ray spectrum model with Spekpy for each voltage.
        s = sp.Spek(kvp=simkV, th=ta, dk=1,z=1, mas=mas_list[case_i], char=True)
        k, phi_k = s.get_spectrum(edges=False)  # Retrieve energy bins and fluence spectrum [Photons cm^-2 keV^-1]

        # Adjust the fluence for the detector pixel area.
        phi_k = phi_k * ((ct_info['psize'][0] / 10) * (ct_info['psize'][1] / 10))  # Convert pixel size from mm² to cm²

        # Initialize a zero-filled spectrum array with length max_simkV.
        src_spec = np.zeros(max_simkV-1)
        src_spec[:simkV-1] = phi_k  # Assign spectrum values starting from 1.5 keV

        # Add the processed spectrum for this voltage to the list.
        src_spec_list.append(src_spec)

src_spec_list = np.array(src_spec_list)
src_spec_list = src_spec_list.reshape((len(voltage_list),len(takeoff_angles),-1))

# %%
# Configure the Reflection Source Model
# Reflection_Source is a PyTorch module that supports gradient descent.
# Reflection_Source initializes with specified source voltage and takeoff angle.
# The set_src_spec_list method assigns a dictionary for each source configuration.
# Reflection_Source.forward() provides interpolated dictionary components for each source.

# Source voltage is set to be fixed by setting minbound and maxbound to None.
# Takeoff angle is estimated in range [5,45] with inital value 25 degree.
sources = [Reflection_Source(voltage=(voltage, None, None), takeoff_angle=(25, 5, 45), single_takeoff_angle=True)
           for voltage in voltage_list]
# Assigning the dictionaries for each source.
for src_i, source in enumerate(sources):
    source.set_src_spec_list(energies, src_spec_list, voltage_list, takeoff_angles)

# %%
# Both the filter and scintillator contain discrete and continuous parameters.
# All continuous parameters are defined using a tuple format with an initial value, minimum bound, and maximum bound.
# Any other format is recognized as a discrete parameter.
# Concatenating all component instances (sources, filters, scintillator) into a list, called spectral configuration like [source, filter_1, scintillator_1], 
# allows the Estimator defined in B07 to recognize all parameters, whether discrete or continuous for a scan.
# The spec_models collects all spectral configuration. Each spectral configuration corresponding to a scan.
# The Estimator will then automatically determine all possible combinations for the discrete parameters and optimize the continous parameters.


# Configure Filter Model
# Knowns: Use one filter for both scans.
# Possible filter materials: Al and Cu.
psb_fltr_mat = [Material(formula='Al', density=2.702), 
                Material(formula='Cu', density=8.92)]
filter_1 = Filter(psb_fltr_mat, thickness=(5, 0, 10))

# Configure Scintillator Model
# Knowns: Use one scintillator for both scans.
# Possible scintillator materials
scint_params_list = [
    {'formula': 'CsI', 'density': 4.51},
    {'formula': 'Gd3Al2Ga3O12', 'density': 6.63},
    {'formula': 'Lu3Al5O12', 'density': 6.73},
    {'formula': 'CdWO4', 'density': 7.9},
    {'formula': 'Y3Al5O12', 'density': 4.56},
    {'formula': 'Bi4Ge3O12', 'density': 7.13},
    {'formula': 'Gd2O2S', 'density': 7.32}
]
psb_scint_mat = [Material(formula=scint_p['formula'], density=scint_p['density']) for scint_p in scint_params_list]
scintillator_1 = Scintillator(materials=psb_scint_mat, thickness=(0.25, 0.01, 0.5))

# For each scan using a different source voltage, we define a different total spectral model.
# Each spectral model is a list containing source, filters, and scintillator models. 
# Allow filter_1, ..., filter_n.
spec_models = [[source, filter_1, scintillator_1] for source in sources]

# %% [markdown]
# ### B06. Spectral Calibration with Simulated Multi-Energy Data

# %%
trans_list[0].shape
# Out:
# (64, 50, 512)

# %%
# Build Training Set
# Use first 8 views and center 2 slices.
train_rads = [trans[::ct_info["NViews"]//NViews_For_MBSC,10:-10:10] for trans in trans_list]

# Assume a same forward matrix for different scans at different voltages.
forward_matrices = [est_spec_F[:,10:-10:10] for i in range(len(voltage_list))]

print("Training Measurement Shape: \n", train_rads[0].shape,train_rads[1].shape,train_rads[2].shape)
print("Training Forward Matrix Shape: \n",forward_matrices[0].shape,forward_matrices[1].shape,forward_matrices[2].shape)
# Out:
# Training Measurement Shape:
#  (8, 3, 512) (8, 3, 512) (8, 3, 512)
# Training Forward Matrix Shape:
#  (8, 3, 512, 179) (8, 3, 512, 179) (8, 3, 512, 179)

# %%
est_spec_F.shape
# Out:
# (8, 50, 512, 179)

# %%
plt.plot(trans_list[0][0,0])
plt.plot(est_spec_F[0,0,:,30])

# %%
from xcal.estimate import Estimate

learning_rate = 0.01 # 0.01 for NNAT_LBFGS and 0.001 for Adam
max_iterations = 5000 # 5000 ~ 10000 would be enough
stop_threshold = 1e-6
optimizer_type = 'NNAT_LBFGS' # Can also use Adam.

Estimator = Estimate(energies)
# For each scan, add data and calculated forward matrix to Estimator.
for nrad, forward_matrix, concatenate_models in zip(train_rads, forward_matrices, spec_models):
    Estimator.add_data(nrad, forward_matrix, concatenate_models, weight=None)

# Fit data
Estimator.fit(learning_rate=learning_rate,
              max_iterations=max_iterations,
              stop_threshold=stop_threshold,
              optimizer_type=optimizer_type,
              loss_type='transmission',
              logpath=None,
              num_processes=4) # Parallel computing for multiple cpus.
# Out:
# Number of cases for different discrete parameters: 14
# 2025-05-05 17:22:58,071  - Start Estimation.
# 2025-05-05 17:22:58,071  - Start Estimation.
# 2025-05-05 17:22:58,071  - Start Estimation.
# 2025-05-05 17:22:58,071  - Start Estimation.
# 2025-05-05 17:22:58,179  - Initial cost: 3.310367e-03
# 2025-05-05 17:22:58,183  - Initial cost: 1.691803e-03
# 2025-05-05 17:22:58,183  - Initial cost: 3.245921e-03
# 2025-05-05 17:22:58,189  - Initial cost: 2.693573e-03
# 2025-05-05 17:22:59,160  - Iteration: 5
# 2025-05-05 17:22:59,166  - Iteration: 5
# 2025-05-05 17:22:59,177  - Iteration: 5
# 2025-05-05 17:22:59,210  - Iteration: 5
# 2025-05-05 17:22:59,392  - Cost: 0.0030298077035695314
# 2025-05-05 17:22:59,392  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:22:59,393  - Filter_3_thickness: 4.462798118591309
# 2025-05-05 17:22:59,393  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:22:59,393  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:22:59,393  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:22:59,393  - Reflection_Source_takeoff_angle: 23.786184310913086
# 2025-05-05 17:22:59,393  - Scintillator_3_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-05 17:22:59,393  - Scintillator_3_thickness: 0.25944921374320984
# 2025-05-05 17:22:59,393  -
# 2025-05-05 17:22:59,406  - Cost: 0.0007787196082063019
# 2025-05-05 17:22:59,407  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:22:59,407  - Filter_3_thickness: 4.245565414428711
# 2025-05-05 17:22:59,407  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:22:59,407  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:22:59,407  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:22:59,407  - Reflection_Source_takeoff_angle: 25.248172760009766
# 2025-05-05 17:22:59,407  - Scintillator_3_material: Material(formula='CsI', density=4.51)
# 2025-05-05 17:22:59,407  - Scintillator_3_thickness: 0.25360313057899475
# 2025-05-05 17:22:59,407  -
# 2025-05-05 17:22:59,419  - Cost: 0.0014895591884851456
# 2025-05-05 17:22:59,420  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:22:59,420  - Filter_3_thickness: 3.8353686332702637
# 2025-05-05 17:22:59,420  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:22:59,420  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:22:59,420  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:22:59,420  - Reflection_Source_takeoff_angle: 25.001445770263672
# 2025-05-05 17:22:59,420  - Scintillator_3_material: Material(formula='CdWO4', density=7.9)
# 2025-05-05 17:22:59,420  - Scintillator_3_thickness: 0.2628251016139984
# 2025-05-05 17:22:59,420  -
# 2025-05-05 17:22:59,470  - Cost: 0.002424470381811261
# 2025-05-05 17:22:59,470  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:22:59,470  - Filter_3_thickness: 4.573503017425537
# 2025-05-05 17:22:59,470  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:22:59,470  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:22:59,470  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:22:59,470  - Reflection_Source_takeoff_angle: 24.291818618774414
# 2025-05-05 17:22:59,470  - Scintillator_3_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-05 17:22:59,470  - Scintillator_3_thickness: 0.2455672025680542
# 2025-05-05 17:22:59,470  -
# 2025-05-05 17:23:00,401  - Iteration: 10
# 2025-05-05 17:23:00,411  - Iteration: 10
# 2025-05-05 17:23:00,443  - Iteration: 10
# 2025-05-05 17:23:00,502  - Iteration: 10
# 2025-05-05 17:23:00,719  - Cost: 0.002535905223339796
# 2025-05-05 17:23:00,719  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:00,719  - Filter_3_thickness: 3.249978542327881
# 2025-05-05 17:23:00,719  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:00,719  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:00,719  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:00,719  - Reflection_Source_takeoff_angle: 16.85842514038086
# 2025-05-05 17:23:00,719  - Scintillator_3_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-05 17:23:00,719  - Scintillator_3_thickness: 0.3191166818141937
# 2025-05-05 17:23:00,719  -
# 2025-05-05 17:23:00,734  - Cost: 0.0006478573195636272
# 2025-05-05 17:23:00,734  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:00,734  - Filter_3_thickness: 3.9681038856506348
# 2025-05-05 17:23:00,734  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:00,734  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:00,734  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:00,734  - Reflection_Source_takeoff_angle: 24.952943801879883
# 2025-05-05 17:23:00,734  - Scintillator_3_material: Material(formula='CsI', density=4.51)
# 2025-05-05 17:23:00,734  - Scintillator_3_thickness: 0.2631680369377136
# 2025-05-05 17:23:00,734  -
# 2025-05-05 17:23:00,762  - Cost: 0.0011185265611857176
# 2025-05-05 17:23:00,762  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:00,763  - Filter_3_thickness: 3.280579090118408
# 2025-05-05 17:23:00,763  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:00,763  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:00,763  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:00,763  - Reflection_Source_takeoff_angle: 24.019390106201172
# 2025-05-05 17:23:00,763  - Scintillator_3_material: Material(formula='CdWO4', density=7.9)
# 2025-05-05 17:23:00,764  - Scintillator_3_thickness: 0.2957632839679718
# 2025-05-05 17:23:00,764  -
# 2025-05-05 17:23:00,806  - Cost: 0.0022337292321026325
# 2025-05-05 17:23:00,806  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:00,806  - Filter_3_thickness: 4.075634002685547
# 2025-05-05 17:23:00,806  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:00,806  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:00,806  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:00,806  - Reflection_Source_takeoff_angle: 20.640987396240234
# 2025-05-05 17:23:00,806  - Scintillator_3_material: Material(formula='Gd3Al2Ga3O12', density=6.63)
# 2025-05-05 17:23:00,806  - Scintillator_3_thickness: 0.24085372686386108
# 2025-05-05 17:23:00,806  -
# 2025-05-05 17:23:01,900  - Iteration: 15
# 2025-05-05 17:23:01,952  - Iteration: 15
# 2025-05-05 17:23:02,131  - Cost: 0.000602060928940773
# 2025-05-05 17:23:02,131  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:02,131  - Filter_3_thickness: 3.787327289581299
# 2025-05-05 17:23:02,131  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:02,131  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:02,131  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:02,131  - Reflection_Source_takeoff_angle: 24.346054077148438
# 2025-05-05 17:23:02,131  - Scintillator_3_material: Material(formula='CsI', density=4.51)
# 2025-05-05 17:23:02,131  - Scintillator_3_thickness: 0.2784556746482849
# 2025-05-05 17:23:02,131  -
# 2025-05-05 17:23:02,184  - Cost: 0.0008844819385558367
# 2025-05-05 17:23:02,184  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:02,184  - Filter_3_thickness: 2.8756093978881836
# 2025-05-05 17:23:02,184  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:02,184  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:02,184  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:02,184  - Reflection_Source_takeoff_angle: 21.921615600585938
# 2025-05-05 17:23:02,184  - Scintillator_3_material: Material(formula='CdWO4', density=7.9)
# 2025-05-05 17:23:02,184  - Scintillator_3_thickness: 0.34620749950408936
# 2025-05-05 17:23:02,184  -
# 2025-05-05 17:23:03,046  - Iteration: 20
# 2025-05-05 17:23:03,111  - Iteration: 20
# 2025-05-05 17:23:03,273  - Cost: 0.0005417128559201956
# 2025-05-05 17:23:03,273  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:03,273  - Filter_3_thickness: 3.5707650184631348
# 2025-05-05 17:23:03,273  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:03,273  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:03,273  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:03,273  - Reflection_Source_takeoff_angle: 22.581823348999023
# 2025-05-05 17:23:03,273  - Scintillator_3_material: Material(formula='CsI', density=4.51)
# 2025-05-05 17:23:03,273  - Scintillator_3_thickness: 0.3168580234050751
# 2025-05-05 17:23:03,273  -
# 2025-05-05 17:23:03,331  - Cost: 0.000617352721747011
# 2025-05-05 17:23:03,331  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:03,331  - Filter_3_thickness: 2.5567495822906494
# 2025-05-05 17:23:03,331  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:03,331  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:03,331  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:03,332  - Reflection_Source_takeoff_angle: 16.681833267211914
# 2025-05-05 17:23:03,332  - Scintillator_3_material: Material(formula='CdWO4', density=7.9)
# 2025-05-05 17:23:03,332  - Scintillator_3_thickness: 0.4127589762210846
# 2025-05-05 17:23:03,332  -
# 2025-05-05 17:23:04,081  - Iteration: 25
# 2025-05-05 17:23:04,129  - Iteration: 25
# 2025-05-05 17:23:04,326  - Cost: 0.0005665698554366827
# 2025-05-05 17:23:04,326  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:04,326  - Filter_3_thickness: 2.419070243835449
# 2025-05-05 17:23:04,326  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:04,326  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:04,326  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:04,326  - Reflection_Source_takeoff_angle: 14.108222961425781
# 2025-05-05 17:23:04,326  - Scintillator_3_material: Material(formula='CdWO4', density=7.9)
# 2025-05-05 17:23:04,326  - Scintillator_3_thickness: 0.43493425846099854
# 2025-05-05 17:23:04,326  -
# 2025-05-05 17:23:04,368  - Cost: 0.0004940292565152049
# 2025-05-05 17:23:04,368  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:04,368  - Filter_3_thickness: 3.429652214050293
# 2025-05-05 17:23:04,368  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:04,368  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:04,368  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:04,368  - Reflection_Source_takeoff_angle: 20.072505950927734
# 2025-05-05 17:23:04,368  - Scintillator_3_material: Material(formula='CsI', density=4.51)
# 2025-05-05 17:23:04,368  - Scintillator_3_thickness: 0.3548256754875183
# 2025-05-05 17:23:04,368  -
# 2025-05-05 17:23:05,003  - Stopping at epoch 13 because updates are too small.
# 2025-05-05 17:23:05,003  - Cost: 0.0022058819886296988
# 2025-05-05 17:23:05,003  - Filter_3_material: Material(formula='Al', density=2.702)
# 2025-05-05 17:23:05,003  - Filter_3_thickness: 2.4807662963867188
# 2025-05-05 17:23:05,003  - Reflection_Source_4_voltage: 40.0
# 2025-05-05 17:23:05,003  - Reflection_Source_5_voltage: 80.0
# 2025-05-05 17:23:05,003  - Reflection_Source_6_voltage: 180.0
# 2025-05-05 17:23:05,003  - Reflection_Source_takeoff_angle: 11.093626022338867
# 2025-05-05 17:23:05,003  - Scintillator_3_material: Material(formula='Lu3Al5O12', density=6.73)
# 2025-05-05 17:23:05,003  - Scintillator_3_thickness: 0.3651432394981384
# 2025-05-05 17:23:05,003  -
# 2025-05-05 17:23:05,009  - Start Estimation.
# 2025-05-05 17:23:05,075  - Initial cost: 6.181131e-03

# %% [markdown]
# ### B07. Result Analysis

# %%
import torch

# Get the estimated effective response for each source voltage.
# Make sure to convert to numpy array from tensor before plotting.
est_sp = Estimator.get_spectra()

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i in range(3):
    ax = axs[i]
    with torch.no_grad():
        ax.plot(energies[:voltage_list[i]-1], (gt_spec_list[i]/np.trapezoid(gt_spec_list[i],energies))[:voltage_list[i]-1],
                label='Ground Truth')
        es = est_sp[i].numpy()
        es /= np.trapezoid(es,energies)
        ax.plot(energies[:voltage_list[i]-1], es[:voltage_list[i]-1], '--', label='Estimate')

    ax.legend()
    ax.set_title(f'{voltage_list[i]} kV Spectral Response')

fig.suptitle('Comparison of Ground Truth and Estimate')
plt.show()

# %%
import pandas as pd

# Return a dictionary containing the estimated parameters.
res_params = Estimator.get_params()

# Ground Truth values
ground_truth = {
    "takeoff_angle (degree)": takeoff_angle,
    "fltr_mat": fltr_mat,
    "fltr_th (mm)": fltr_th,
    "det_mat": det_mat,
    "det_th (mm)": det_th,
}

# Estimated values from res_params
# .item() to return value for an estiamted continous parameter.
# material with .formula is because the class Material contains both formula and density.
estimated = {
    "takeoff_angle (degree)": res_params['Reflection_Source_takeoff_angle'].item(),
    "fltr_mat": res_params['Filter_2_material'].formula,
    "fltr_th (mm)": res_params['Filter_2_thickness'].item(),
    "det_mat": res_params['Scintillator_2_material'].formula,
    "det_th (mm)": res_params['Scintillator_2_thickness'].item(),
}

# Combine into a DataFrame for comparison
df = pd.DataFrame({'Ground Truth': ground_truth, 'Estimated': estimated})

# Display the DataFrame
df
